# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhiss123/AlmaBetter-Projects/blob/main/Another_copy_of_Numerical_Programming_in_Python_Web_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Web Scraping & Data Handling Challenge**

# %% [markdown]
# ### **Website:**
# JustWatch -  https://www.justwatch.com/in/movies?release_year_from=2000
#
#
# ### **Description:**
#
# JustWatch is a popular platform that allows users to search for movies and TV shows across multiple streaming services like Netflix, Amazon Prime, Hulu, etc. For this assignment, you will be required to scrape movie and TV show data from JustWatch using Selenium, Python, and BeautifulSoup. Extract data from HTML, not by directly calling their APIs. Then, perform data filtering and analysis using Pandas, and finally, save the results to a CSV file.
#
# ### **Tasks:**
#
# **1. Web Scraping:**
#
# Use BeautifulSoup to scrape the following data from JustWatch:
#
#    **a. Movie Information:**
#
#       - Movie title
#       - Release year
#       - Genre
#       - IMDb rating
#       - Streaming services available (Netflix, Amazon Prime, Hulu, etc.)
#       - URL to the movie page on JustWatch
#
#    **b. TV Show Information:**
#
#       - TV show title
#       - Release year
#       - Genre
#       - IMDb rating
#       - Streaming services available (Netflix, Amazon Prime, Hulu, etc.)
#       - URL to the TV show page on JustWatch
#
#   **c. Scope:**
#
# ```
#  ` - Scrape data for at least 50 movies and 50 TV shows.
#    - You can choose the entry point (e.g., starting with popular movies,
#      or a specific genre, etc.) to ensure a diverse dataset.`
#
# ```
#
#
# **2. Data Filtering & Analysis:**
#
#    After scraping the data, use Pandas to perform the following tasks:
#
#    **a. Filter movies and TV shows based on specific criteria:**
#
#    ```
#       - Only include movies and TV shows released in the last 2 years (from the current date).
#       - Only include movies and TV shows with an IMDb rating of 7 or higher.
# ```
#
#    **b. Data Analysis:**
#
#    ```
#       - Calculate the average IMDb rating for the scraped movies and TV shows.
#       - Identify the top 5 genres that have the highest number of available movies and TV shows.
#       - Determine the streaming service with the most significant number of offerings.
#
#    ```
#
# **3. Data Export:**
#
# ```
#    - Dump the filtered and analysed data into a CSV file for further processing and reporting.
#
#    - Keep the CSV file in your Drive Folder and Share the Drive link on the colab while keeping view access with anyone.
# ```
#
# **Submission:**
# ```
# - Submit a link to your Colab made for the assignment.
#
# - The Colab should contain your Python script (.py format only) with clear
#   comments explaining the scraping, filtering, and analysis process.
#
# - Your Code shouldn't have any errors and should be executable at a one go.
#
# - Before Conclusion, Keep your Dataset Drive Link in the Notebook.
# ```
#
#
#
# **Note:**
#
# 1. Properly handle errors and exceptions during web scraping to ensure a robust script.
#
# 2. Make sure your code is well-structured, easy to understand, and follows Python best practices.
#
# 3. The assignment will be evaluated based on the correctness of the scraped data, accuracy of data filtering and analysis, and the overall quality of the Python code.

# %% [markdown]
# # **Start The Project**

# %% [markdown]
# ## **Task 1:- Web Scrapping**

# %%
#Installing all necessary labraries
# !pip install beautifulsoup4
# !pip install requests
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.6.2)

# %%
#import all necessary labraries
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np

# %% [markdown]
# ## **Scrapping Movies Data**

# %%
# Specifying the URL from which movies related data will be fetched
url="https://www.justwatch.com/in/movies"

# Sending an HTTP GET request to the URL
page=requests.get(url)
# Parsing the HTML content using BeautifulSoup with the 'html.parser'
soup=BeautifulSoup(page.text,'html.parser')
# Printing the prettified HTML content
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>
#  403
# </title>
# 403 Forbidden

# %% [markdown]
# ## **Fetching Movie URL's**

# %%
# Write Your Code here
# Finding all movie_elements with the specified class
movie_elements = soup.find_all('a', class_='title-list-grid__item--link')

# Initializing an empty list to store the movie URLs
movie_urls = []

# Loop through each movie_element and extract the 'href' attribute
for movie_element in movie_elements:
  href_value = movie_element.get('href')
  full_url = f'https://www.justwatch.com{href_value}'
  movie_urls.append(full_url)

# Printing the list of movie URLs
print(movie_urls)
# Out:
# ['https://www.justwatch.com/in/movie/laapataa-ladies', 'https://www.justwatch.com/in/movie/article-370', 'https://www.justwatch.com/in/movie/manjummel-boys', 'https://www.justwatch.com/in/movie/family-star', 'https://www.justwatch.com/in/movie/black-magic-2024', 'https://www.justwatch.com/in/movie/premalu', 'https://www.justwatch.com/in/movie/dune-part-two', 'https://www.justwatch.com/in/movie/aavesham-2024', 'https://www.justwatch.com/in/movie/the-crew-2024', 'https://www.justwatch.com/in/movie/untitled-shahid-kapoor-kriti-sanon-film', 'https://www.justwatch.com/in/movie/yodha-2022', 'https://www.justwatch.com/in/movie/godzilla-x-kong-the-new-empire', 'https://www.justwatch.com/in/movie/oppenheimer', 'https://www.justwatch.com/in/movie/hanu-man', 'https://www.justwatch.com/in/movie/anyone-but-you', 'https://www.justwatch.com/in/movie/monkey-man', 'https://www.justwatch.com/in/movie/madgaon-express', 'https://www.justwatch.com/in/movie/kung-fu-panda-4', 'https://www.justwatch.com/in/movie/amar-singh-chamkila', 'https://www.justwatch.com/in/movie/tillu-square', 'https://www.justwatch.com/in/movie/dune-2021', 'https://www.justwatch.com/in/movie/the-beekeeper-2024', 'https://www.justwatch.com/in/movie/animal-2022', 'https://www.justwatch.com/in/movie/777-charlie', 'https://www.justwatch.com/in/movie/godzilla-minus-one', 'https://www.justwatch.com/in/movie/anatomie-dune-chute', 'https://www.justwatch.com/in/movie/12th-fail', 'https://www.justwatch.com/in/movie/the-idea-of-you', 'https://www.justwatch.com/in/movie/hereditary', 'https://www.justwatch.com/in/movie/dj-tillu', 'https://www.justwatch.com/in/movie/kampon', 'https://www.justwatch.com/in/movie/365-days', 'https://www.justwatch.com/in/movie/salaar', 'https://www.justwatch.com/in/movie/fighter-2022', 'https://www.justwatch.com/in/movie/crakk-jeetegaa-toh-jiyegaa', 'https://www.justwatch.com/in/movie/bramayugam', 'https://www.justwatch.com/in/movie/sam-bahadur', 'https://www.justwatch.com/in/movie/madame-web', 'https://www.justwatch.com/in/movie/the-raid', 'https://www.justwatch.com/in/movie/harry-potter-and-the-philosophers-stone', 'https://www.justwatch.com/in/movie/poor-things', 'https://www.justwatch.com/in/movie/rebel-moon-part-two-the-scargiver', 'https://www.justwatch.com/in/movie/wild-tales', 'https://www.justwatch.com/in/movie/rise-of-the-planet-of-the-apes', 'https://www.justwatch.com/in/movie/kung-fu-panda', 'https://www.justwatch.com/in/movie/anchakkallakokkan', 'https://www.justwatch.com/in/movie/silence-2-the-night-owl-bar-shootout', 'https://www.justwatch.com/in/movie/bade-miyan-chote-miyan-2023', 'https://www.justwatch.com/in/movie/challengers', 'https://www.justwatch.com/in/movie/aquaman-and-the-lost-kingdom', 'https://www.justwatch.com/in/movie/migration', 'https://www.justwatch.com/in/movie/speak-no-evil-2022', 'https://www.justwatch.com/in/movie/romeo-2024', 'https://www.justwatch.com/in/movie/all-india-rank', 'https://www.justwatch.com/in/movie/aadujeevitham', 'https://www.justwatch.com/in/movie/maidaan', 'https://www.justwatch.com/in/movie/late-night-with-the-devil', 'https://www.justwatch.com/in/movie/ranam-2024', 'https://www.justwatch.com/in/movie/the-kerala-story', 'https://www.justwatch.com/in/movie/exhuma', 'https://www.justwatch.com/in/movie/ravening', 'https://www.justwatch.com/in/movie/dear-2024', 'https://www.justwatch.com/in/movie/pushpa', 'https://www.justwatch.com/in/movie/road-house-2024', 'https://www.justwatch.com/in/movie/the-fall-guy', 'https://www.justwatch.com/in/movie/gaami', 'https://www.justwatch.com/in/movie/the-lord-of-the-rings-the-fellowship-of-the-ring', 'https://www.justwatch.com/in/movie/godzilla-vs-kong', 'https://www.justwatch.com/in/movie/zara-hatke-zara-bach-ke', 'https://www.justwatch.com/in/movie/argylle', 'https://www.justwatch.com/in/movie/veppam-kulir-mazhai', 'https://www.justwatch.com/in/movie/siren-2024', 'https://www.justwatch.com/in/movie/the-gangster-the-cop-the-devil', 'https://www.justwatch.com/in/movie/may- ...

# %% [markdown]
# ## **Scrapping Movie Title**

# %%
# Write Your Code here
# Initializing an empty list to store movie titles
movie_title = []

# Iterating through each movie_element in the list
for movie_element in movie_elements:
    # Extracting the movie title from the 'href' attribute of the movie_element
    name = movie_element.get('href').split('/')[-1].strip()

    # Appending the movie title to the 'movie_title' list
    movie_title.append(name)

# Printing the list of movie titles
print(movie_title)
# Out:
# ['laapataa-ladies', 'article-370', 'manjummel-boys', 'family-star', 'black-magic-2024', 'premalu', 'dune-part-two', 'aavesham-2024', 'the-crew-2024', 'untitled-shahid-kapoor-kriti-sanon-film', 'yodha-2022', 'godzilla-x-kong-the-new-empire', 'oppenheimer', 'hanu-man', 'anyone-but-you', 'monkey-man', 'madgaon-express', 'kung-fu-panda-4', 'amar-singh-chamkila', 'tillu-square', 'dune-2021', 'the-beekeeper-2024', 'animal-2022', '777-charlie', 'godzilla-minus-one', 'anatomie-dune-chute', '12th-fail', 'the-idea-of-you', 'hereditary', 'dj-tillu', 'kampon', '365-days', 'salaar', 'fighter-2022', 'crakk-jeetegaa-toh-jiyegaa', 'bramayugam', 'sam-bahadur', 'madame-web', 'the-raid', 'harry-potter-and-the-philosophers-stone', 'poor-things', 'rebel-moon-part-two-the-scargiver', 'wild-tales', 'rise-of-the-planet-of-the-apes', 'kung-fu-panda', 'anchakkallakokkan', 'silence-2-the-night-owl-bar-shootout', 'bade-miyan-chote-miyan-2023', 'challengers', 'aquaman-and-the-lost-kingdom', 'migration', 'speak-no-evil-2022', 'romeo-2024', 'all-india-rank', 'aadujeevitham', 'maidaan', 'late-night-with-the-devil', 'ranam-2024', 'the-kerala-story', 'exhuma', 'ravening', 'dear-2024', 'pushpa', 'road-house-2024', 'the-fall-guy', 'gaami', 'the-lord-of-the-rings-the-fellowship-of-the-ring', 'godzilla-vs-kong', 'zara-hatke-zara-bach-ke', 'argylle', 'veppam-kulir-mazhai', 'siren-2024', 'the-gangster-the-cop-the-devil', 'may-december', '13-bom-di-jakarta', 'k-g-f-chapter-2', 'bhimaa', 'civil-war-2024-0', 'wonka', 'war-for-the-planet-of-the-apes', 'kingdom-of-the-planet-of-the-apes', 'kaam-chalu-hai', 'dada-2023', 'ghostbusters-frozen-empire', 'joram', 'the-intern', 'operation-valentine', 'hatching', 'chaari-111', 'om-bheem-bush', 'antrum', 'omg-2', 'joker-2019', 'interstellar', 'the-wolf-of-wall-street', 'the-spacewalker', 'dawn-of-the-planet-of-the-apes', 'kaagaz-2', 'kingdom-of-heaven', 'abigail-2024']

# %% [markdown]
# ## **Scrapping release Year**

# %%
# Write Your Code here
# Initializing an empty list to store release years
release_year = []

# Iterating through each movie URL
for url in movie_urls:
    # Fetching the webpage content
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    # Finding the span element with class 'text-muted'
    year = soup.find('span', {'class':'text-muted'})

    # Extracting the release year using string manipulation
    # If 'year' is not found, assign 'NA' as the default value
    release_year.append(year.text.split("(")[-1].split(")")[0] if year else 'NA')

# Printing the list of release years
print(release_year)
# Out:
# ['2024', '2024', '2024', '2024', '2024', '2024', '2024', '2024', '2024', '2024', '2024', '2024', '2023', '2024', '2023', '2024', '2024', '2024', '2024', '2024', '2021', '2024', '2023', '2022', '2023', '2023', '2023', '2024', '2018', '2022', '2023', '2020', '2023', '2024', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '2024', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '2023', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']

# %% [markdown]
# ## **Scrapping Genres**

# %%
# Write Your Code here
# Initializing a dictionary to store genre values for each movie URL
genres = {}

# Iterating through each movie URL
for url in movie_urls:
    # Fetching the webpage content
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')

    # Finding all div elements with class 'detail-infos'
    details_divs = soup.find_all('div', {'class':'detail-infos'})

    # Default value for genre in case it's not found
    genre_value = 'NA'

    # Iterating through each 'detail-infos' div
    for detail_div in details_divs:
        # Finding the h3 element with class 'detail-infos__subheading'
        subheading = detail_div.find('h3', {'class':'detail-infos__subheading'})

        # Checking if the subheading contains the text 'genres'
        if subheading and 'Genres' in subheading.text:
            # Finding the next div with class 'detail-infos__value'
            genre_div = detail_div.find('div', {'class':'detail-infos__value'})

            # Checking if the genre_div is found
            if genre_div:
                # Extracting the genre value
               genre_value = genre_div.text.strip()

    # Storing the genre_value in the dictionary with the movie URL as the key
    genres[url] = genre_value

# Print the dictionary containing genre values for each movie URL
print(genres)
# Out:
# {'https://www.justwatch.com/in/movie/laapataa-ladies': 'Drama, Comedy', 'https://www.justwatch.com/in/movie/article-370': 'Action & Adventure, Drama, Mystery & Thriller', 'https://www.justwatch.com/in/movie/manjummel-boys': 'Mystery & Thriller, Action & Adventure, Drama', 'https://www.justwatch.com/in/movie/family-star': 'Action & Adventure, Drama, Comedy, Romance', 'https://www.justwatch.com/in/movie/black-magic-2024': 'NA', 'https://www.justwatch.com/in/movie/premalu': 'NA', 'https://www.justwatch.com/in/movie/dune-part-two': 'NA', 'https://www.justwatch.com/in/movie/aavesham-2024': 'NA', 'https://www.justwatch.com/in/movie/the-crew-2024': 'NA', 'https://www.justwatch.com/in/movie/untitled-shahid-kapoor-kriti-sanon-film': 'NA', 'https://www.justwatch.com/in/movie/yodha-2022': 'NA', 'https://www.justwatch.com/in/movie/godzilla-x-kong-the-new-empire': 'NA', 'https://www.justwatch.com/in/movie/oppenheimer': 'NA', 'https://www.justwatch.com/in/movie/hanu-man': 'NA', 'https://www.justwatch.com/in/movie/anyone-but-you': 'NA', 'https://www.justwatch.com/in/movie/monkey-man': 'NA', 'https://www.justwatch.com/in/movie/madgaon-express': 'NA', 'https://www.justwatch.com/in/movie/kung-fu-panda-4': 'NA', 'https://www.justwatch.com/in/movie/amar-singh-chamkila': 'NA', 'https://www.justwatch.com/in/movie/tillu-square': 'NA', 'https://www.justwatch.com/in/movie/dune-2021': 'NA', 'https://www.justwatch.com/in/movie/the-beekeeper-2024': 'NA', 'https://www.justwatch.com/in/movie/animal-2022': 'NA', 'https://www.justwatch.com/in/movie/777-charlie': 'Action & Adventure, Comedy, Drama', 'https://www.justwatch.com/in/movie/godzilla-minus-one': 'NA', 'https://www.justwatch.com/in/movie/anatomie-dune-chute': 'NA', 'https://www.justwatch.com/in/movie/12th-fail': 'NA', 'https://www.justwatch.com/in/movie/the-idea-of-you': 'NA', 'https://www.justwatch.com/in/movie/hereditary': 'NA', 'https://www.justwatch.com/in/movie/dj-tillu': 'NA', 'https://www.justwatch.com/in/movie/kampon': 'NA', 'https://www.justwatch.com/in/movie/365-days': 'NA', 'https://www.justwatch.com/in/movie/salaar': 'NA', 'https://www.justwatch.com/in/movie/fighter-2022': 'NA', 'https://www.justwatch.com/in/movie/crakk-jeetegaa-toh-jiyegaa': 'NA', 'https://www.justwatch.com/in/movie/bramayugam': 'NA', 'https://www.justwatch.com/in/movie/sam-bahadur': 'NA', 'https://www.justwatch.com/in/movie/madame-web': 'NA', 'https://www.justwatch.com/in/movie/the-raid': 'NA', 'https://www.justwatch.com/in/movie/harry-potter-and-the-philosophers-stone': 'NA', 'https://www.justwatch.com/in/movie/poor-things': 'NA', 'https://www.justwatch.com/in/movie/rebel-moon-part-two-the-scargiver': 'NA', 'https://www.justwatch.com/in/movie/wild-tales': 'NA', 'https://www.justwatch.com/in/movie/rise-of-the-planet-of-the-apes': 'NA', 'https://www.justwatch.com/in/movie/kung-fu-panda': 'NA', 'https://www.justwatch.com/in/movie/anchakkallakokkan': 'NA', 'https://www.justwatch.com/in/movie/silence-2-the-night-owl-bar-shootout': 'NA', 'https://www.justwatch.com/in/movie/bade-miyan-chote-miyan-2023': 'NA', 'https://www.justwatch.com/in/movie/challengers': 'Romance, Drama, Sport', 'https://www.justwatch.com/in/movie/aquaman-and-the-lost-kingdom': 'NA', 'https://www.justwatch.com/in/movie/migration': 'NA', 'https://www.justwatch.com/in/movie/speak-no-evil-2022': 'NA', 'https://www.justwatch.com/in/movie/romeo-2024': 'NA', 'https://www.justwatch.com/in/movie/all-india-rank': 'NA', 'https://www.justwatch.com/in/movie/aadujeevitham': 'NA', 'https://www.justwatch.com/in/movie/maidaan': 'NA', 'https://www.justwatch.com/in/movie/late-night-with-the-devil': 'NA', 'https://www.justwatch.com/in/movie/ranam-2024': 'NA', 'https://www.justwatch.com/in/movie/the-kerala-story': 'NA', 'https://www.justwatch.com/in/movie/exhuma': 'NA', 'https://www.justwatch.com/in/movie/ravening': 'NA', 'https://www.justwatch.com/in/movie/dear-2024': 'NA', 'https://www.justwatch.com/in/movie/pushpa': 'NA', 'https://www.justwatch.com/in/movie/road-house-202 ...

# %%
# Initializing an empty list to store genre
movie_genre=[]

# Iterate through each value in the 'genres' dictionary

for genre in genres.values():
  movie_genre.append(genre)

print(movie_genre)
# Out:
# ['Drama, Comedy', 'Action & Adventure, Drama, Mystery & Thriller', 'Mystery & Thriller, Action & Adventure, Drama', 'Action & Adventure, Drama, Comedy, Romance', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'Action & Adventure, Comedy, Drama', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'Romance, Drama, Sport', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'Mystery & Thriller, Action & Adventure, Crime', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'Drama, Science-Fiction', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']

# %% [markdown]
# ## **Scrapping IMBD Rating**

# %%
# Write Your Code here
# Initializing a dictionary to store rating values for each movie URL
ratings = {}

# Iterating through each movie URL
for url in movie_urls:
    # Fetching the webpage content
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')

    # Finding all div elements with class 'detail-infos'
    details_divs = soup.find_all('div', {'class':'detail-infos'})

    # Default value for rating in case it's not found
    rating_value = 'NA'

    # Iterating through each 'detail-infos' div
    for detail_div in details_divs:
        # Finding the h3 element with class 'detail-infos__subheading'
        subheading = detail_div.find('h3', {'class':'detail-infos__subheading'})

        # Checking if the subheading contains the text 'Rating'
        if subheading and 'Rating' in subheading.text:
            # Finding the next div with class 'detail-infos__value'
            rating_div = detail_div.find('div', {'class':'detail-infos__value'})

            # Checking if the rating_div is found
            if rating_div:
                # Extracting the rating value
                rating_value = rating_div.text.strip()


    # Storing the rating value in the dictionary with the movie URL as the key
    ratings[url] = rating_value

# Print the dictionary containing rating values for each movie URL
print(ratings)
# Out:
# {'https://www.justwatch.com/in/movie/laapataa-ladies': '8.5  (20k)', 'https://www.justwatch.com/in/movie/article-370': '8.0  (17k)', 'https://www.justwatch.com/in/movie/manjummel-boys': '8.4  (11k)', 'https://www.justwatch.com/in/movie/family-star': '5.1  (2k)', 'https://www.justwatch.com/in/movie/black-magic-2024': '6.8  (41k)', 'https://www.justwatch.com/in/movie/premalu': 'NA', 'https://www.justwatch.com/in/movie/dune-part-two': 'NA', 'https://www.justwatch.com/in/movie/aavesham-2024': 'NA', 'https://www.justwatch.com/in/movie/the-crew-2024': 'NA', 'https://www.justwatch.com/in/movie/untitled-shahid-kapoor-kriti-sanon-film': 'NA', 'https://www.justwatch.com/in/movie/yodha-2022': 'NA', 'https://www.justwatch.com/in/movie/godzilla-x-kong-the-new-empire': 'NA', 'https://www.justwatch.com/in/movie/oppenheimer': 'NA', 'https://www.justwatch.com/in/movie/hanu-man': 'NA', 'https://www.justwatch.com/in/movie/anyone-but-you': 'NA', 'https://www.justwatch.com/in/movie/monkey-man': 'NA', 'https://www.justwatch.com/in/movie/madgaon-express': 'NA', 'https://www.justwatch.com/in/movie/kung-fu-panda-4': 'NA', 'https://www.justwatch.com/in/movie/amar-singh-chamkila': 'NA', 'https://www.justwatch.com/in/movie/tillu-square': 'NA', 'https://www.justwatch.com/in/movie/dune-2021': 'NA', 'https://www.justwatch.com/in/movie/the-beekeeper-2024': 'NA', 'https://www.justwatch.com/in/movie/animal-2022': 'NA', 'https://www.justwatch.com/in/movie/777-charlie': 'NA', 'https://www.justwatch.com/in/movie/godzilla-minus-one': 'NA', 'https://www.justwatch.com/in/movie/anatomie-dune-chute': 'NA', 'https://www.justwatch.com/in/movie/12th-fail': 'NA', 'https://www.justwatch.com/in/movie/the-idea-of-you': 'NA', 'https://www.justwatch.com/in/movie/hereditary': 'NA', 'https://www.justwatch.com/in/movie/dj-tillu': 'NA', 'https://www.justwatch.com/in/movie/kampon': 'NA', 'https://www.justwatch.com/in/movie/365-days': 'NA', 'https://www.justwatch.com/in/movie/salaar': 'NA', 'https://www.justwatch.com/in/movie/fighter-2022': 'NA', 'https://www.justwatch.com/in/movie/crakk-jeetegaa-toh-jiyegaa': 'NA', 'https://www.justwatch.com/in/movie/bramayugam': 'NA', 'https://www.justwatch.com/in/movie/sam-bahadur': 'NA', 'https://www.justwatch.com/in/movie/madame-web': '3.9  (58k)', 'https://www.justwatch.com/in/movie/the-raid': 'NA', 'https://www.justwatch.com/in/movie/harry-potter-and-the-philosophers-stone': 'NA', 'https://www.justwatch.com/in/movie/poor-things': 'NA', 'https://www.justwatch.com/in/movie/rebel-moon-part-two-the-scargiver': 'NA', 'https://www.justwatch.com/in/movie/wild-tales': 'NA', 'https://www.justwatch.com/in/movie/rise-of-the-planet-of-the-apes': 'NA', 'https://www.justwatch.com/in/movie/kung-fu-panda': 'NA', 'https://www.justwatch.com/in/movie/anchakkallakokkan': 'NA', 'https://www.justwatch.com/in/movie/silence-2-the-night-owl-bar-shootout': 'NA', 'https://www.justwatch.com/in/movie/bade-miyan-chote-miyan-2023': 'NA', 'https://www.justwatch.com/in/movie/challengers': 'NA', 'https://www.justwatch.com/in/movie/aquaman-and-the-lost-kingdom': 'NA', 'https://www.justwatch.com/in/movie/migration': 'NA', 'https://www.justwatch.com/in/movie/speak-no-evil-2022': 'NA', 'https://www.justwatch.com/in/movie/romeo-2024': 'NA', 'https://www.justwatch.com/in/movie/all-india-rank': 'NA', 'https://www.justwatch.com/in/movie/aadujeevitham': 'NA', 'https://www.justwatch.com/in/movie/maidaan': 'NA', 'https://www.justwatch.com/in/movie/late-night-with-the-devil': 'NA', 'https://www.justwatch.com/in/movie/ranam-2024': 'NA', 'https://www.justwatch.com/in/movie/the-kerala-story': 'NA', 'https://www.justwatch.com/in/movie/exhuma': 'NA', 'https://www.justwatch.com/in/movie/ravening': 'NA', 'https://www.justwatch.com/in/movie/dear-2024': 'NA', 'https://www.justwatch.com/in/movie/pushpa': '7.6  (87k)', 'https://www.justwatch.com/in/movie/road-house-2024': 'NA', 'https://www.justwatch.com/in/movie/the-fall-guy': 'NA', 'https://www.justwatch.com/in/movie/gaami': 'NA', 'https://www.ju ...

# %%
# Initializing an empty list to store IMDb ratings
imdb_rating=[]

# Iterate through each value in the 'ratings' dictionary
for rating in ratings.values():
  imdb_rating.append(rating.split()[0])

# Print the list of IMDb ratings
print(imdb_rating)
# Out:
# ['8.5', '8.0', '8.4', '5.1', '6.8', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '3.9', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '7.6', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '5.2', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']

# %% [markdown]
# ## **Scrapping Runtime/Duration**

# %%
# Write Your Code here
# Initializing a dictionary to store runtime values for each movie URL
runtime = {}

# Iterating through each movie URL
for url in movie_urls:
    # Fetching the webpage content
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    # Finding all div elements with class 'detail-infos'
    details_divs = soup.find_all('div', {'class':'detail-infos'})

    # Default value for runtime in case it's not found
    runtime_value = 'NA'

    # Iterating through each 'detail-infos' div
    for detail_div in details_divs:
        # Finding the h3 element with class 'detail-infos__subheading'
        subheading = detail_div.find('h3', {'class':'detail-infos__subheading'})

        # Checking if the subheading contains the text 'Runtime'
        if subheading and 'Runtime' in subheading.text:
            # Finding the next div with class 'detail-infos__value'
            runtime_div = detail_div.find('div', {'class':'detail-infos__value'})

            # Checking if the runtime_div is found
            if runtime_div:
                # Extracting the runtime value
                runtime_value = runtime_div.text.strip()

    # Storing the runtime value in the dictionary with the movie URL as the key
    runtime[url] = runtime_value

# Print the dictionary containing runtime values for each movie URL
print(runtime)
# Out:
# {'https://www.justwatch.com/in/movie/laapataa-ladies': '2h 2min', 'https://www.justwatch.com/in/movie/article-370': '2h 38min', 'https://www.justwatch.com/in/movie/manjummel-boys': '2h 15min', 'https://www.justwatch.com/in/movie/family-star': '2h 39min', 'https://www.justwatch.com/in/movie/black-magic-2024': '2h 12min', 'https://www.justwatch.com/in/movie/premalu': '2h 36min', 'https://www.justwatch.com/in/movie/dune-part-two': '2h 47min', 'https://www.justwatch.com/in/movie/aavesham-2024': '2h 38min', 'https://www.justwatch.com/in/movie/the-crew-2024': '1h 58min', 'https://www.justwatch.com/in/movie/untitled-shahid-kapoor-kriti-sanon-film': '2h 21min', 'https://www.justwatch.com/in/movie/yodha-2022': '2h 10min', 'https://www.justwatch.com/in/movie/godzilla-x-kong-the-new-empire': '1h 55min', 'https://www.justwatch.com/in/movie/oppenheimer': 'NA', 'https://www.justwatch.com/in/movie/hanu-man': 'NA', 'https://www.justwatch.com/in/movie/anyone-but-you': 'NA', 'https://www.justwatch.com/in/movie/monkey-man': 'NA', 'https://www.justwatch.com/in/movie/madgaon-express': 'NA', 'https://www.justwatch.com/in/movie/kung-fu-panda-4': 'NA', 'https://www.justwatch.com/in/movie/amar-singh-chamkila': 'NA', 'https://www.justwatch.com/in/movie/tillu-square': '2h 17min', 'https://www.justwatch.com/in/movie/dune-2021': 'NA', 'https://www.justwatch.com/in/movie/the-beekeeper-2024': 'NA', 'https://www.justwatch.com/in/movie/animal-2022': 'NA', 'https://www.justwatch.com/in/movie/777-charlie': 'NA', 'https://www.justwatch.com/in/movie/godzilla-minus-one': 'NA', 'https://www.justwatch.com/in/movie/anatomie-dune-chute': 'NA', 'https://www.justwatch.com/in/movie/12th-fail': 'NA', 'https://www.justwatch.com/in/movie/the-idea-of-you': 'NA', 'https://www.justwatch.com/in/movie/hereditary': 'NA', 'https://www.justwatch.com/in/movie/dj-tillu': 'NA', 'https://www.justwatch.com/in/movie/kampon': 'NA', 'https://www.justwatch.com/in/movie/365-days': 'NA', 'https://www.justwatch.com/in/movie/salaar': 'NA', 'https://www.justwatch.com/in/movie/fighter-2022': 'NA', 'https://www.justwatch.com/in/movie/crakk-jeetegaa-toh-jiyegaa': 'NA', 'https://www.justwatch.com/in/movie/bramayugam': 'NA', 'https://www.justwatch.com/in/movie/sam-bahadur': 'NA', 'https://www.justwatch.com/in/movie/madame-web': 'NA', 'https://www.justwatch.com/in/movie/the-raid': 'NA', 'https://www.justwatch.com/in/movie/harry-potter-and-the-philosophers-stone': 'NA', 'https://www.justwatch.com/in/movie/poor-things': 'NA', 'https://www.justwatch.com/in/movie/rebel-moon-part-two-the-scargiver': 'NA', 'https://www.justwatch.com/in/movie/wild-tales': '2h 2min', 'https://www.justwatch.com/in/movie/rise-of-the-planet-of-the-apes': 'NA', 'https://www.justwatch.com/in/movie/kung-fu-panda': 'NA', 'https://www.justwatch.com/in/movie/anchakkallakokkan': 'NA', 'https://www.justwatch.com/in/movie/silence-2-the-night-owl-bar-shootout': 'NA', 'https://www.justwatch.com/in/movie/bade-miyan-chote-miyan-2023': 'NA', 'https://www.justwatch.com/in/movie/challengers': 'NA', 'https://www.justwatch.com/in/movie/aquaman-and-the-lost-kingdom': 'NA', 'https://www.justwatch.com/in/movie/migration': 'NA', 'https://www.justwatch.com/in/movie/speak-no-evil-2022': 'NA', 'https://www.justwatch.com/in/movie/romeo-2024': 'NA', 'https://www.justwatch.com/in/movie/all-india-rank': 'NA', 'https://www.justwatch.com/in/movie/aadujeevitham': 'NA', 'https://www.justwatch.com/in/movie/maidaan': 'NA', 'https://www.justwatch.com/in/movie/late-night-with-the-devil': 'NA', 'https://www.justwatch.com/in/movie/ranam-2024': 'NA', 'https://www.justwatch.com/in/movie/the-kerala-story': 'NA', 'https://www.justwatch.com/in/movie/exhuma': 'NA', 'https://www.justwatch.com/in/movie/ravening': 'NA', 'https://www.justwatch.com/in/movie/dear-2024': 'NA', 'https://www.justwatch.com/in/movie/pushpa': 'NA', 'https://www.justwatch.com/in/movie/road-house-2024': 'NA', 'https://www.justwatch.com/in/movie/the-fall-guy': 'NA', 'https://www.justwatch.com/in/movie/ga ...

# %%
# Initializing an empty list to store movie_runtime values
movie_runtime = []

# Iterate through each value in the 'runtime' dictionary
for time in runtime.values():
    # Append the runtime value to the 'movie_runtime' list
    movie_runtime.append(time)

# Print the list of movie_runtime values
print(movie_runtime)
# Out:
# ['2h 2min', '2h 38min', '2h 15min', '2h 39min', '2h 12min', '2h 36min', '2h 47min', '2h 38min', '1h 58min', '2h 21min', '2h 10min', '1h 55min', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '2h 17min', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '2h 2min', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '2h 59min', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '1h 31min', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']

# %% [markdown]
# ## **Scrapping Age Rating**

# %%
# Write Your Code here
# Initializing a dictionary to store age criteria for each movie URL
age_criteria = {}

# Iterating through each movie URL
for url in movie_urls:
    # Fetching the webpage content
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    # Finding all div elements with class 'detail-infos'
    details_divs = soup.find_all('div', {'class':'detail-infos'})

    # Default value for age_rating in case it's not found
    age_rating = 'NA'

    # Iterating through each 'detail-infos' div
    for detail_div in details_divs:
        # Finding the h3 element with class 'detail-infos__subheading'
        subheading = detail_div.find('h3', {'class':'detail-infos__subheading'})

        # Checking if the subheading contains the text 'Age Rating'
        if subheading and 'Age rating' in subheading.text:
            # Finding the next div with class 'detail-infos__value'
            age_rating_div = detail_div.find('div', {'class':'detail-infos__value'})

            # Checking if the age_rating_div is found
            if age_rating_div:
                # Extracting the age rating value
                age_rating = age_rating_div.text.strip()

    # Storing the age rating value in the dictionary with the movie URL as the key
    age_criteria[url] =age_rating

# Print the dictionary containing age_rating_value values for each movie URL
print(age_criteria)
# Out:
# {'https://www.justwatch.com/in/movie/laapataa-ladies': 'UA', 'https://www.justwatch.com/in/movie/article-370': 'NA', 'https://www.justwatch.com/in/movie/manjummel-boys': 'UA', 'https://www.justwatch.com/in/movie/family-star': 'NA', 'https://www.justwatch.com/in/movie/black-magic-2024': 'UA', 'https://www.justwatch.com/in/movie/premalu': 'U', 'https://www.justwatch.com/in/movie/dune-part-two': 'NA', 'https://www.justwatch.com/in/movie/aavesham-2024': 'NA', 'https://www.justwatch.com/in/movie/the-crew-2024': 'NA', 'https://www.justwatch.com/in/movie/untitled-shahid-kapoor-kriti-sanon-film': 'NA', 'https://www.justwatch.com/in/movie/yodha-2022': 'NA', 'https://www.justwatch.com/in/movie/godzilla-x-kong-the-new-empire': 'NA', 'https://www.justwatch.com/in/movie/oppenheimer': 'NA', 'https://www.justwatch.com/in/movie/hanu-man': 'NA', 'https://www.justwatch.com/in/movie/anyone-but-you': 'NA', 'https://www.justwatch.com/in/movie/monkey-man': 'NA', 'https://www.justwatch.com/in/movie/madgaon-express': 'NA', 'https://www.justwatch.com/in/movie/kung-fu-panda-4': 'NA', 'https://www.justwatch.com/in/movie/amar-singh-chamkila': 'NA', 'https://www.justwatch.com/in/movie/tillu-square': 'NA', 'https://www.justwatch.com/in/movie/dune-2021': 'NA', 'https://www.justwatch.com/in/movie/the-beekeeper-2024': 'NA', 'https://www.justwatch.com/in/movie/animal-2022': 'NA', 'https://www.justwatch.com/in/movie/777-charlie': 'NA', 'https://www.justwatch.com/in/movie/godzilla-minus-one': 'NA', 'https://www.justwatch.com/in/movie/anatomie-dune-chute': 'NA', 'https://www.justwatch.com/in/movie/12th-fail': 'NA', 'https://www.justwatch.com/in/movie/the-idea-of-you': 'NA', 'https://www.justwatch.com/in/movie/hereditary': 'NA', 'https://www.justwatch.com/in/movie/dj-tillu': 'NA', 'https://www.justwatch.com/in/movie/kampon': 'NA', 'https://www.justwatch.com/in/movie/365-days': 'NA', 'https://www.justwatch.com/in/movie/salaar': 'A', 'https://www.justwatch.com/in/movie/fighter-2022': 'NA', 'https://www.justwatch.com/in/movie/crakk-jeetegaa-toh-jiyegaa': 'NA', 'https://www.justwatch.com/in/movie/bramayugam': 'NA', 'https://www.justwatch.com/in/movie/sam-bahadur': 'NA', 'https://www.justwatch.com/in/movie/madame-web': 'NA', 'https://www.justwatch.com/in/movie/the-raid': 'NA', 'https://www.justwatch.com/in/movie/harry-potter-and-the-philosophers-stone': 'NA', 'https://www.justwatch.com/in/movie/poor-things': 'NA', 'https://www.justwatch.com/in/movie/rebel-moon-part-two-the-scargiver': 'NA', 'https://www.justwatch.com/in/movie/wild-tales': 'NA', 'https://www.justwatch.com/in/movie/rise-of-the-planet-of-the-apes': 'NA', 'https://www.justwatch.com/in/movie/kung-fu-panda': 'NA', 'https://www.justwatch.com/in/movie/anchakkallakokkan': 'NA', 'https://www.justwatch.com/in/movie/silence-2-the-night-owl-bar-shootout': 'NA', 'https://www.justwatch.com/in/movie/bade-miyan-chote-miyan-2023': 'NA', 'https://www.justwatch.com/in/movie/challengers': 'NA', 'https://www.justwatch.com/in/movie/aquaman-and-the-lost-kingdom': 'NA', 'https://www.justwatch.com/in/movie/migration': 'NA', 'https://www.justwatch.com/in/movie/speak-no-evil-2022': 'NA', 'https://www.justwatch.com/in/movie/romeo-2024': 'NA', 'https://www.justwatch.com/in/movie/all-india-rank': 'NA', 'https://www.justwatch.com/in/movie/aadujeevitham': 'NA', 'https://www.justwatch.com/in/movie/maidaan': 'NA', 'https://www.justwatch.com/in/movie/late-night-with-the-devil': 'NA', 'https://www.justwatch.com/in/movie/ranam-2024': 'NA', 'https://www.justwatch.com/in/movie/the-kerala-story': 'NA', 'https://www.justwatch.com/in/movie/exhuma': 'NA', 'https://www.justwatch.com/in/movie/ravening': 'NA', 'https://www.justwatch.com/in/movie/dear-2024': 'NA', 'https://www.justwatch.com/in/movie/pushpa': 'NA', 'https://www.justwatch.com/in/movie/road-house-2024': 'NA', 'https://www.justwatch.com/in/movie/the-fall-guy': 'NA', 'https://www.justwatch.com/in/movie/gaami': 'NA', 'https://www.justwatch.com/in/movie/the-lord-of-the-rings-the-fellowship ...

# %%
# Initializing an empty list to store age_rating values
age_rating =[]

# Iterate through each value in the 'age_criteria' dictionary
for age in age_criteria.values():
  age_rating.append(age)

# Print the list of age ratings
print(age_rating)
# Out:
# ['UA', 'NA', 'UA', 'NA', 'UA', 'U', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'A', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'A', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'A', 'NA']

# %% [markdown]
# ## **Fetching Production Countries Details**

# %%
# Write Your Code here
# Initializing a dictionary to store production_countries for each movie URL
production_countries = {}

# Iterating through each movie URL
for url in movie_urls:
    # Fetching the webpage content
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    # Finding all div elements with class 'detail-infos'
    details_divs = soup.find_all('div', {'class':'detail-infos'})

    # Default value for production country in case it's not found
    country = 'NA'

    # Iterating through each 'detail-infos' div
    for detail_div in details_divs:
        # Finding the h3 element with class 'detail-infos__subheading'
        subheading = detail_div.find('h3', {'class':'detail-infos__subheading'})

        # Checking if the subheading contains the text 'Production country'
        if subheading and 'Production country' in subheading.text:
            # Finding the next div with class 'detail-infos__value'
            country_div = detail_div.find('div', {'class':'detail-infos__value'})

            # Checking if the country_div is found
            if country_div:
                # Extracting the country name
                country = country_div .text.strip()

    # Storing the country name  in the dictionary with the movie URL as the key
    production_countries[url] =country

# Print the dictionary containing counry for each movie URL
print(production_countries)
# Out:
# {'https://www.justwatch.com/in/movie/laapataa-ladies': 'India', 'https://www.justwatch.com/in/movie/article-370': 'India', 'https://www.justwatch.com/in/movie/manjummel-boys': 'NA', 'https://www.justwatch.com/in/movie/family-star': 'NA', 'https://www.justwatch.com/in/movie/black-magic-2024': 'NA', 'https://www.justwatch.com/in/movie/premalu': 'NA', 'https://www.justwatch.com/in/movie/dune-part-two': 'United States', 'https://www.justwatch.com/in/movie/aavesham-2024': 'NA', 'https://www.justwatch.com/in/movie/the-crew-2024': 'NA', 'https://www.justwatch.com/in/movie/untitled-shahid-kapoor-kriti-sanon-film': 'NA', 'https://www.justwatch.com/in/movie/yodha-2022': 'NA', 'https://www.justwatch.com/in/movie/godzilla-x-kong-the-new-empire': 'NA', 'https://www.justwatch.com/in/movie/oppenheimer': 'NA', 'https://www.justwatch.com/in/movie/hanu-man': 'NA', 'https://www.justwatch.com/in/movie/anyone-but-you': 'NA', 'https://www.justwatch.com/in/movie/monkey-man': 'NA', 'https://www.justwatch.com/in/movie/madgaon-express': 'NA', 'https://www.justwatch.com/in/movie/kung-fu-panda-4': 'NA', 'https://www.justwatch.com/in/movie/amar-singh-chamkila': 'NA', 'https://www.justwatch.com/in/movie/tillu-square': 'NA', 'https://www.justwatch.com/in/movie/dune-2021': 'NA', 'https://www.justwatch.com/in/movie/the-beekeeper-2024': 'NA', 'https://www.justwatch.com/in/movie/animal-2022': 'NA', 'https://www.justwatch.com/in/movie/777-charlie': 'NA', 'https://www.justwatch.com/in/movie/godzilla-minus-one': 'NA', 'https://www.justwatch.com/in/movie/anatomie-dune-chute': 'NA', 'https://www.justwatch.com/in/movie/12th-fail': 'NA', 'https://www.justwatch.com/in/movie/the-idea-of-you': 'United States', 'https://www.justwatch.com/in/movie/hereditary': 'NA', 'https://www.justwatch.com/in/movie/dj-tillu': 'NA', 'https://www.justwatch.com/in/movie/kampon': 'NA', 'https://www.justwatch.com/in/movie/365-days': 'NA', 'https://www.justwatch.com/in/movie/salaar': 'NA', 'https://www.justwatch.com/in/movie/fighter-2022': 'NA', 'https://www.justwatch.com/in/movie/crakk-jeetegaa-toh-jiyegaa': 'NA', 'https://www.justwatch.com/in/movie/bramayugam': 'NA', 'https://www.justwatch.com/in/movie/sam-bahadur': 'NA', 'https://www.justwatch.com/in/movie/madame-web': 'NA', 'https://www.justwatch.com/in/movie/the-raid': 'NA', 'https://www.justwatch.com/in/movie/harry-potter-and-the-philosophers-stone': 'NA', 'https://www.justwatch.com/in/movie/poor-things': 'NA', 'https://www.justwatch.com/in/movie/rebel-moon-part-two-the-scargiver': 'NA', 'https://www.justwatch.com/in/movie/wild-tales': 'NA', 'https://www.justwatch.com/in/movie/rise-of-the-planet-of-the-apes': 'NA', 'https://www.justwatch.com/in/movie/kung-fu-panda': 'NA', 'https://www.justwatch.com/in/movie/anchakkallakokkan': 'NA', 'https://www.justwatch.com/in/movie/silence-2-the-night-owl-bar-shootout': 'NA', 'https://www.justwatch.com/in/movie/bade-miyan-chote-miyan-2023': 'NA', 'https://www.justwatch.com/in/movie/challengers': 'NA', 'https://www.justwatch.com/in/movie/aquaman-and-the-lost-kingdom': 'NA', 'https://www.justwatch.com/in/movie/migration': 'United States', 'https://www.justwatch.com/in/movie/speak-no-evil-2022': 'NA', 'https://www.justwatch.com/in/movie/romeo-2024': 'NA', 'https://www.justwatch.com/in/movie/all-india-rank': 'NA', 'https://www.justwatch.com/in/movie/aadujeevitham': 'NA', 'https://www.justwatch.com/in/movie/maidaan': 'NA', 'https://www.justwatch.com/in/movie/late-night-with-the-devil': 'NA', 'https://www.justwatch.com/in/movie/ranam-2024': 'NA', 'https://www.justwatch.com/in/movie/the-kerala-story': 'NA', 'https://www.justwatch.com/in/movie/exhuma': 'NA', 'https://www.justwatch.com/in/movie/ravening': 'NA', 'https://www.justwatch.com/in/movie/dear-2024': 'NA', 'https://www.justwatch.com/in/movie/pushpa': 'NA', 'https://www.justwatch.com/in/movie/road-house-2024': 'NA', 'https://www.justwatch.com/in/movie/the-fall-guy': 'NA', 'https://www.justwatch.com/in/movie/gaami': 'NA', 'https://www.justwatch.com/in/m ...

# %%
# Initializing an empty list to store production_country values
production_country=[]

# Iterate through each value in the 'production_countries' dictionary
for country in production_countries.values():
  production_country.append(country)

# Print the list of age ratings
print(production_country)
# Out:
# ['India', 'India', 'NA', 'NA', 'NA', 'NA', 'United States', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'United States', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'United States', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'Indonesia, South Korea', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'United Kingdom, United States', 'NA', 'NA', 'NA']

# %% [markdown]
# ## **Fetching Streaming Service Details**

# %%
# Write Your Code here

# Initializing an empty list to store streaming platform names
streaming_platform = []

# Iterating through each movie URL
for url in movie_urls:
    # Fetching the webpage content
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    # Finding the img element with class 'offer__icon'
    platform = soup.find('img', {'class':'offer__icon'})

    # Checking if the platform element is found
    if platform:
        # Extracting the 'alt' attribute, which contains the platform name
        platform_name = platform['alt']
    else:
        # Setting platform_name to 'NA' if the platform element is not found
        platform_name = "NA"

    # Handling the specific case where the platform_name is 'Bookmyshow'
    # Appending 'NA' to the list in this case
    if platform_name == 'Bookmyshow':
        streaming_platform.append('NA')
    else:
        # Appending the platform_name to the list
        streaming_platform.append(platform_name)

# Print the list of streaming platform names
print(streaming_platform)
# Out:
# ['Netflix', 'Netflix', 'Hotstar', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'Apple TV', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'Amazon Prime Video', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'Amazon Prime Video', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'Amazon Prime Video', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']

# %% [markdown]
# ## **Now Creating Movies DataFrame**

# %%
# Write Your Code here
# Creating a dictionary with keys as column names and values as lists
movie_data = {
                'Title': movie_title,
                'Release_year': release_year,
                'Genre': movie_genre,
                'IMDB_Rating': imdb_rating,
                'Age_rating': age_rating,
                'Duration':movie_runtime ,
                'Production_country': production_country,
                'Streaming_service': streaming_platform,
                'URL': movie_urls
              }

# Creating a DataFrame using the dictionary
movie_df = pd.DataFrame(movie_data)

movie_df
# Out:
#                              Title Release_year  \
# 0                  laapataa-ladies         2024
# 1                      article-370         2024
# 2                   manjummel-boys         2024
# 3                      family-star         2024
# 4                 black-magic-2024         2024
# ..                             ...          ...
# 95                 the-spacewalker           NA
# 96  dawn-of-the-planet-of-the-apes           NA
# 97                        kaagaz-2           NA
# 98               kingdom-of-heaven           NA
# 99                    abigail-2024           NA
#
#                                             Genre IMDB_Rating Age_rating  \
# 0                                   Drama, Comedy         8.5         UA
# 1   Action & Adventure, Drama, Mystery & Thriller         8.0         NA
# 2   Mystery & Thriller, Action & Adventure, Drama         8.4         UA
# 3      Action & Adventure, Drama, Comedy, Romance         5.1         NA
# 4                                              NA         6.8         UA
# ..                                            ...         ...        ...
# 95                                             NA          NA         NA
# 96                                             NA          NA         NA
# 97                                             NA          NA         NA
# 98                                             NA          NA          A
# 99                                             NA          NA         NA
#
#     Duration             Production_country Streaming_service  \
# 0    2h 2min                          India           Netflix
# 1   2h 38min                          India           Netflix
# 2   2h 15min                             NA           Hotstar
# 3   2h 39min                             NA                NA
# 4   2h 12min                             NA                NA
# ..       ...                            ...               ...
# 95        NA                             NA                NA
# 96        NA  United Kingdom, United States                NA
# 97        NA                             NA                NA
# 98        NA                             NA                NA
# 99        NA                             NA                NA
#
#                                                   URL
# 0   https://www.justwatch.com/in/movie/laapataa-la...
# 1      https://www.justwatch.com/in/movie/article-370
# 2   https://www.justwatch.com/in/movie/manjummel-boys
# 3      https://www.justwatch.com/in/movie/family-star
# 4   https://www.justwatch.com/in/movie/black-magic...
# ..                                                ...
# 95  https://www.justwatch.com/in/movie/the-spacewa...
# 96  https://www.justwatch.com/in/movie/dawn-of-the...
# 97        https://www.justwatch.com/in/movie/kaagaz-2
# 98  https://www.justwatch.com/in/movie/kingdom-of-...
# 99    https://www.justwatch.com/in/movie/abigail-2024
#
# [100 rows x 9 columns]

# %%
#head of dataframe
movie_df.head(10)
# Out:
#                                      Title Release_year  \
# 0                          laapataa-ladies         2024
# 1                              article-370         2024
# 2                           manjummel-boys         2024
# 3                              family-star         2024
# 4                         black-magic-2024         2024
# 5                                  premalu         2024
# 6                            dune-part-two         2024
# 7                            aavesham-2024         2024
# 8                            the-crew-2024         2024
# 9  untitled-shahid-kapoor-kriti-sanon-film         2024
#
#                                            Genre IMDB_Rating Age_rating  \
# 0                                  Drama, Comedy         8.5         UA
# 1  Action & Adventure, Drama, Mystery & Thriller         8.0         NA
# 2  Mystery & Thriller, Action & Adventure, Drama         8.4         UA
# 3     Action & Adventure, Drama, Comedy, Romance         5.1         NA
# 4                                             NA         6.8         UA
# 5                                             NA          NA          U
# 6                                             NA          NA         NA
# 7                                             NA          NA         NA
# 8                                             NA          NA         NA
# 9                                             NA          NA         NA
#
#    Duration Production_country Streaming_service  \
# 0   2h 2min              India           Netflix
# 1  2h 38min              India           Netflix
# 2  2h 15min                 NA           Hotstar
# 3  2h 39min                 NA                NA
# 4  2h 12min                 NA                NA
# 5  2h 36min                 NA                NA
# 6  2h 47min      United States                NA
# 7  2h 38min                 NA                NA
# 8  1h 58min                 NA                NA
# 9  2h 21min                 NA                NA
#
#                                                  URL
# 0  https://www.justwatch.com/in/movie/laapataa-la...
# 1     https://www.justwatch.com/in/movie/article-370
# 2  https://www.justwatch.com/in/movie/manjummel-boys
# 3     https://www.justwatch.com/in/movie/family-star
# 4  https://www.justwatch.com/in/movie/black-magic...
# 5         https://www.justwatch.com/in/movie/premalu
# 6   https://www.justwatch.com/in/movie/dune-part-two
# 7   https://www.justwatch.com/in/movie/aavesham-2024
# 8   https://www.justwatch.com/in/movie/the-crew-2024
# 9  https://www.justwatch.com/in/movie/untitled-sh...

# %%
#info of data
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               100 non-null    object
#  1   Release_year        100 non-null    object
#  2   Genre               100 non-null    object
#  3   IMDB_Rating         100 non-null    object
#  4   Age_rating          100 non-null    object
#  5   Duration            100 non-null    object
#  6   Production_country  100 non-null    object
#  7   Streaming_service   100 non-null    object
#  8   URL                 100 non-null    object
# dtypes: object(9)
# memory usage: 7.2+ KB

# %%
# Replace 'NA' with NaN (Not a Number)
movie_df['IMDB_Rating'].replace('NA', float('nan'), inplace=True)

# Convert the 'IMDB_Rating' column to float
movie_df['IMDB_Rating'] = movie_df['IMDB_Rating'].astype(float)
movie_df['IMDB_Rating']
# Out:
# 0     8.5
# 1     8.0
# 2     8.4
# 3     5.1
# 4     6.8
#      ...
# 95    NaN
# 96    NaN
# 97    NaN
# 98    NaN
# 99    NaN
# Name: IMDB_Rating, Length: 100, dtype: float64

# %% [markdown]
# ## **Scraping TV  Show Data**

# %%
# Specifying the URL from which tv show related data will be fetched
tv_url='https://www.justwatch.com/in/tv-shows?release_year_from=2000'
# Sending an HTTP GET request to the URL
page=requests.get(tv_url)
# Parsing the HTML content using BeautifulSoup with the 'html.parser'
soup=BeautifulSoup(page.text,'html.parser')
# Printing the prettified HTML content
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-vue-meta="%7B%22dir%22:%7B%22ssr%22:%22ltr%22%7D,%22lang%22:%7B%22ssr%22:%22en%22%7D%7D" data-vue-meta-server-rendered="" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8" data-vue-meta="ssr"/>
#   <meta content="IE=edge" data-vue-meta="ssr" httpequiv="X-UA-Compatible"/>
#   <meta content="viewport-fit=cover, width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" data-vue-meta="ssr" name="viewport"/>
#   <meta content="JustWatch" data-vue-meta="ssr" property="og:site_name"/>
#   <meta content="794243977319785" data-vue-meta="ssr" property="fb:app_id"/>
#   <meta content="/appassets/img/JustWatch_logo_with_claim.png" data-vmid="og:image" data-vue-meta="ssr" property="og:image"/>
#   <meta content="606" data-vmid="og:image:width" data-vue-meta="ssr" property="og:image:width"/>
#   <meta content="302" data-vmid="og:image:height" data-vue-meta="ssr" property="og:image:height"/>
#   <meta content="yes" data-vue-meta="ssr" name="mobile-web-app-capable"/>
#   <meta content="yes" data-vue-meta="ssr" name="apple-mobile-web-app-capable"/>
#   <meta content="#182531" data-vue-meta="ssr" name="theme-color"/>
#   <meta content="4eBTNBm4L6RaWdF8V51EHZajskAMgXYAg81iRXJqumQ" data-vue-meta="ssr" name="google-site-verification"/>
#   <meta content="d61y4roe8t5xwbb0gfu6gwe8j8iq3i" data-vue-meta="ssr" name="facebook-domain-verification"/>
#   <meta content="dmorpwc4h544ct6mv" data-vue-meta="ssr" name="dailymotion-domain-verification"/>
#   <meta content="Watch series online" data-vmid="og:title" data-vue-meta="ssr" property="og:title"/>
#   <meta content="watch series, watch tv series online, series online, online watch tv shows online, best shows to binge watch, popular tv shows" data-vue-meta="ssr" name="keywords"/>
#   <meta content="Where to watch TV series online? Find with JustWatch all the series you can stream online on Netflix, Hooq, Voot and 10 other streaming providers. Purchase, rent online &amp; flat-rate." data-vmid="description" data-vue-meta="ssr" name="description"/>
#   <meta content="Where to watch TV series online? Find with JustWatch all the series you can stream online on Netflix, Hooq, Voot and 10 other streaming providers. Purchase, rent online &amp; flat-rate." data-vmid="og:description" data-vue-meta="ssr" property="og:description"/>
#   <meta content="noindex, follow" data-vmid="robots" data-vue-meta="ssr" name="robots"/>
#   <title>
#    Watch series online
#   </title>
#   <link as="font" crossorigin="true" data-vue-meta="ssr" href="/appassets/fonts/lato-regular.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="true" data-vue-meta="ssr" href="/appassets/fonts/lato-700.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="true" data-vue-meta="ssr" href="/appassets/fonts/lato-900.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="true" data-vue-meta="ssr" href="/appassets/fonts/anton.woff" rel="preload" type="font/woff2"/>
#   <link data-vue-meta="ssr" href="/appassets/favicon.ico" rel="icon"/>
#   <link crossorigin="use-credentials" data-vue-meta="ssr" href="https://images.justwatch.com" rel="preconnect"/>
#   <link data-vue-meta="ssr" href="https://www.googletagmanager.com/" rel="dns-prefetch"/>
#   <link data-vue-meta="ssr" href="https://ib.adnxs.com" rel="dns-prefetch"/>
#   <link data-vmid="canonical" data-vue-meta="ssr" href="https://www.justwatch.com/in/tv-shows" rel="canonical"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ar/series" hreflang="es-AR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/at/Serien" hreflang="de-AT" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/au/tv-shows" hreflang="en-AU" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/be/series" hreflang="fr-BE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/bg/сериали" hreflang="bg-BG" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/br/series" hreflang="pt-BR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ca/tv-shows" hreflang="en-CA" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ch/Serien" hreflang="de-CH" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/cl/series" hreflang="es-CL" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/co/series" hreflang="es-CO" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/cz/serialy" hreflang="cs-CZ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/de/Serien" hreflang="de-DE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/dk/tv-series" hreflang="en-DK" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ec/series" hreflang="es-EC" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/eg/tv-shows" hreflang="ar-EG" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/es/series" hreflang="es-ES" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/fi/sarjat" hreflang="fi-FI" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/fr/series" hreflang="fr-FR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/uk/tv-series" hreflang="en-GB" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/gr/τηλεοπτικές-σειρές" hreflang="el-GR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/hk/電視節目" hreflang="zh-HK" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/hr/serije" hreflang="hr-HR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/hu/tv-sorozat" hreflang="hu-HU" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ie/tv-series" hreflang="en-IE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/in/tv-shows" hreflang="en-IN" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/iq/tv-shows" hreflang="ar-IQ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/is/þættir" hreflang="is-IS" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/it/serie-tv" hreflang="it-IT" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/jp/テレビ番組" hreflang="ja-JP" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/kr/TV-프로그램" hreflang="ko-KR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/lb/tv-shows" hreflang="ar-LB" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/mx/series" hreflang="es-MX" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/my/tv-shows" hreflang="en-MY" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/nl/tv-series" hreflang="en-NL" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/no/tv-series" hreflang="en-NO" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/nz/tv-shows" hreflang="en-NZ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/pe/series" hreflang="es-PE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ph/tv-shows" hreflang="en-PH" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/pl/seriale" hreflang="pl-PL" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ps/tv-shows" hreflang="ar-PS" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/pt/series" hreflang="pt-PT" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ro/seriale" hreflang="ro-RO" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ru/сериалы" hreflang="ru-RU" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/se/tv-serier" hreflang="sv-SE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/sg/tv-shows" hreflang="en-SG" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/sk/seriály" hreflang="sk-SK" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/tr/tv-dizileri" hreflang="tr-TR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/us/tv-shows" hreflang="en-US" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/va/serie-tv" hreflang="it-VA" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/xk/seriale-televizive" hreflang="sq-XK" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/za/tv-series" hreflang="en-ZA" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ee/seriaalid" hreflang="et-EE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/lt/tv-laidos" hreflang="lt-LT" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/id/tv-shows" hreflang="en-ID" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/tw/電視節目" hreflang="zh-TW" rel="alternate"/>
#   <base href="/" target="_self"/>
#   <link as="image" href="/appassets/img/logo/JustWatch-logo-large.webp" imagesrcset="/appassets/img/logo/JustWatch-logo-large.webp 1px" importance="high" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/207360008/s100/netflix.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/207360008/s100/netflix.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/52449861/s100/amazonprimevideo.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/52449861/s100/amazonprimevideo.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/152862153/s100/appletvplus.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/152862153/s100/appletvplus.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/190848813/s100/itunes.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/190848813/s100/itunes.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/127445869/s100/crunchyroll.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/127445869/s100/crunchyroll.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/240029443/s100/hotstar.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/240029443/s100/hotstar.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/312325227/s100/jiocinema.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/312325227/s100/jiocinema.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/poster/309349704/s166/shogun-2024.webp" imagesrcset="https://www.justwatch.com/images/poster/309349704/s166/shogun-2024.webp 1px, https://www.justwatch.com/images/poster/309349704/s166/shogun-2024.webp" importance="high" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/poster/314549753/s166/heeramandi.webp" imagesrcset="https://www.justwatch.com/images/poster/314549753/s166/heeramandi.webp 1px, https://www.justwatch.com/images/poster/314549753/s166/heeramandi.webp" importance="high" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/poster/307571937/s166/panchayat.webp" imagesrcset="https://www.justwatch.com/images/poster/307571937/s166/panchayat.webp 1px, https://www.justwatch.com/images/poster/307571937/s166/panchayat.webp" importance="high" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/poster/313866771/s166/fallout.webp" imagesrcset="https://www.justwatch.com/images/poster/313866771/s166/fallout.webp 1px, https://www.justwatch.com/images/poster/313866771/s166/fallout.webp" importance="high" rel="preload"/>
#   <style data-vue-ssr-id="16dee5de:0 16dee5de:1 374c0f88:0 4d630dd0:0 60410341:0 0afad778:0 2c4532b4:0 fe68317e:0 5819cd4e:0 389924d2:0 6dcc8ee6:0 2faf257e:0 15ce0433:0 08ddf3ea:0 3fb3f709:0 807844d8:0 77f36025:0 71268dee:0 5c5194c1:0 cf8eefd6:0 6240279c:0 6f8b7108:0 9205deb2:0 4cb87908:0 37592880:0 d9ba2922:0 588ea6ac:0 588933ed:0 03e9b512:0 234f0bb4:0 7a02e26b:0 44770f63:0 3cf28c3e:0 28bf261c:0 0de9810f:0 7fbcc135:0 05def2d1:0">
#    html.ios{--ion-default-font:-apple-system,BlinkMacSystemFont,"Helvetica Neue","Roboto",sans-serif}html.md{--ion-default-font:"Roboto","Helvetica Neue",sans-serif}html{--ion-font-family:var(--ion-default-font)}body{background:var(--ion-background-color)}body.backdrop-no-scroll{overflow:hidden}html.ios ion-modal.modal-card .ion-page>ion-header>ion-toolbar:first-of-type{padding-top:0}html.ios ion-modal .ion-page{border-radius:inherit}.ion-color-primary{--ion-color-base:var(--ion-color-primary,#3880ff)!important;--ion-color-base-rgb:var(--ion-color-primary-rgb,56,128,255)!important;--ion-color-contrast:var(--ion-color-primary-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-primary-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-primary-shade,#3171e0)!important;--ion-color-tint:var(--ion-color-primary-tint,#4c8dff)!important}.ion-color-secondary{--ion-color-base:var(--ion-color-secondary,#3dc2ff)!important;--ion-color-base-rgb:var(--ion-color-secondary-rgb,61,194,255)!important;--ion-color-contrast:var(--ion-color-secondary-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-secondary-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-secondary-shade,#36abe0)!important;--ion-color-tint:var(--ion-color-secondary-tint,#50c8ff)!important}.ion-color-tertiary{--ion-color-base:var(--ion-color-tertiary,#5260ff)!important;--ion-color-base-rgb:var(--ion-color-tertiary-rgb,82,96,255)!important;--ion-color-contrast:var(--ion-color-tertiary-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-tertiary-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-tertiary-shade,#4854e0)!important;--ion-color-tint:var(--ion-color-tertiary-tint,#6370ff)!important}.ion-color-success{--ion-color-base:var(--ion-color-success,#2dd36f)!important;--ion-color-base-rgb:var(--ion-color-success-rgb,45,211,111)!important;--ion-color-contrast:var(--ion-color-success-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-success-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-success-shade,#28ba62)!important;--ion-color-tint:var(--ion-color-success-tint,#42d77d)!important}.ion-color-warning{--ion-color-base:var(--ion-color-warning,#ffc409)!important;--ion-color-base-rgb:var(--ion-color-warning-rgb,255,196,9)!important;--ion-color-contrast:var(--ion-color-warning-contrast,#000)!important;--ion-color-contrast-rgb:var(--ion-color-warning-contrast-rgb,0,0,0)!important;--ion-color-shade:var(--ion-color-warning-shade,#e0ac08)!important;--ion-color-tint:var(--ion-color-warning-tint,#ffca22)!important}.ion-color-danger{--ion-color-base:var(--ion-color-danger,#eb445a)!important;--ion-color-base-rgb:var(--ion-color-danger-rgb,235,68,90)!important;--ion-color-contrast:var(--ion-color-danger-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-danger-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-danger-shade,#cf3c4f)!important;--ion-color-tint:var(--ion-color-danger-tint,#ed576b)!important}.ion-color-light{--ion-color-base:var(--ion-color-light,#f4f5f8)!important;--ion-color-base-rgb:var(--ion-color-light-rgb,244,245,248)!important;--ion-color-contrast:var(--ion-color-light-contrast,#000)!important;--ion-color-contrast-rgb:var(--ion-color-light-contrast-rgb,0,0,0)!important;--ion-color-shade:var(--ion-color-light-shade,#d7d8da)!important;--ion-color-tint:var(--ion-color-light-tint,#f5f6f9)!important}.ion-color-medium{--ion-color-base:var(--ion-color-medium,#92949c)!important;--ion-color-base-rgb:var(--ion-color-medium-rgb,146,148,156)!important;--ion-color-contrast:var(--ion-color-medium-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-medium-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-medium-shade,#808289)!important;--ion-color-tint:var(--ion-color-medium-tint,#9d9fa6)!important}.ion-color-dark{--ion-color-base:var(--ion-color-dark,#222428)!important;--ion-color-b ...
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
#  *//*! Source: https://github.com/h5bp/html5-boilerplate/blob/master/src/css/main.css */@media print{*,:after,:before{color:#000!important;text-shadow:none!important;background:transparent!important;box-shadow:none!important}a,a:visited{text-decoration:underline}a[href]:after{content:" (" attr(href) ")"}abbr[title]:after{content:" (" attr(title) ")"}a[href^="#"]:after,a[href^="javascript:"]:after{content:""}blockquote,pre{border:1px solid #999;page-break-inside:avoid}thead{display:table-header-group}img,tr{page-break-inside:avoid}img{max-width:100%!important}h2,h3,p{orphans:3;widows:3}h2,h3{page-break-after:avoid}.navbar{display:none}.btn>.caret,.dropup>.btn>.caret{border-top-color:#000!important}.label{border:1px solid #000}.table{border-collapse:collapse!important}.table td,.table th{background-color:#fff!important}.table-bordered td,.table-bordered th{border:1px solid #ddd!important}}*,:after,:before{box-sizing:border-box}html{font-size:10px;-webkit-tap-highlight-color:rgba(0,0,0,0)}body{font-family:Lato,Lato-fallback,Arial,sans-serif;font-size:14px;line-height:1.428571429;color:#333;background-color:#fff}button,input,select,textarea{font-family:inherit;font-size:inherit;line-height:inherit}a{color:#428bca}a,a:focus,a:hover{text-decoration:none}a:focus,a:hover{color:#2a6496}a:focus{outline:5px auto -webkit-focus-ring-color;outline-offset:-2px}figure{margin:0}img{vertical-align:middle}.img-responsive{display:block;max-width:100%;height:auto}.img-rounded{border-radius:6px}.img-thumbnail{padding:4px;line-height:1.428571429;background-color:#fff;border:1px solid #ddd;border-radius:4px;transition:all .2s ease-in-out;display:inline-block;max-width:100%;height:auto}.img-circle{border-radius:50%}hr{margin-top:20px;margin-bottom:20px;border:0;border-top:1px solid #eee}.sr-only{position:absolute;width:1px;height:1px;padding:0;margin:-1px;overflow:hidden;clip:rect(0,0,0,0);border:0}.sr-only-focusable:active,.sr-only-focusable:focus{position:static;width:auto;height:auto;margin:0;overflow:visible;clip:auto}[role=button]{cursor:pointer}.container{padding-right:15px;padding-left:15px;margin-right:auto;margin-left:auto}.container:after,.container:before{display:table;content:" "}.container:after{clear:both}@media(min-width:768px){.container{width:750px}}@media(min-width:992px){.container{width:970px}}@media(min-width:1200px){.container{width:1170px}}.container-fluid{padding-right:15px;padding-left:15px;margin-right:auto;margin-left:auto}.container-fluid:after,.container-fluid:before{display:table;content:" "}.container-fluid:after{clear:both}.row{margin-right:-15px;margin-left:-15px}.row:after,.row:before{display:table;content:" "}.row:after{clear:both}.row-no-gutters{margin-right:0;margin-left:0}.row-no-gutters [class*=col-]{padding-right:0;padding-left:0}.col-lg-1,.col-lg-2,.col-lg-3,.col-lg-4,.col-lg-5,.col-lg-6,.col-lg-7,.col-lg-8,.col-lg-9,.col-lg-10,.col-lg-11,.col-lg-12,.col-md-1,.col-md-2,.col-md-3,.col-md-4,.col-md-5,.col-md-6,.col-md-7,.col-md-8,.col-md-9,.col-md-10,.col-md-11,.col-md-12,.col-sm-1,.col-sm-2,.col-sm-3,.col-sm-4,.col-sm-5,.col-sm-6,.col-sm-7,.col-sm-8,.col-sm-9,.col-sm-10,.col-sm-11,.col-sm-12,.col-xs-1,.col-xs-2,.col-xs-3,.col-xs-4,.col-xs-5,.col-xs-6,.col-xs-7,.col-xs-8,.col-xs-9,.col-xs-10,.col-xs-11,.col-xs-12{position:relative;min-height:1px;padding-right:15px;padding-left:15px}.col-xs-1,.col-xs-2,.col-xs-3,.col-xs-4,.col-xs-5,.col-xs-6,.col-xs-7,.col-xs-8,.col-xs-9,.col-xs-10,.col-xs-11,.col-xs-12{float:left}.col-xs-1{width:8.3333333333%}.col-xs-2{width:16.6666666667%}.col-xs-3{width:25%}.col-xs-4{width:33.3333333333%}.col-xs-5{width:41.6666666667%}.col-xs-6{width:50%}.col-xs-7{width:58.3333333333%}.col-xs-8{width:66.6666666667%}.col-xs-9{width:75%}.col-xs-10{width:83.3333333333%}.col-xs-11{width:91.6666666667%}.col-xs-12{width:100%}.col-xs-pull-0{right:auto}.col-xs-pull-1{right:8.3333333333%}.col-xs-pull-2{right:16.6666666667%}.col-xs-pull-3{right:25%}.col-xs-pull-4{right:33.3333333333%}.col-xs-pull-5{right ...
# :host,:root{--fa-font-solid:normal 900 1em/1 "Font Awesome 6 Solid";--fa-font-regular:normal 400 1em/1 "Font Awesome 6 Regular";--fa-font-light:normal 300 1em/1 "Font Awesome 6 Light";--fa-font-thin:normal 100 1em/1 "Font Awesome 6 Thin";--fa-font-duotone:normal 900 1em/1 "Font Awesome 6 Duotone";--fa-font-sharp-solid:normal 900 1em/1 "Font Awesome 6 Sharp";--fa-font-sharp-regular:normal 400 1em/1 "Font Awesome 6 Sharp";--fa-font-sharp-light:normal 300 1em/1 "Font Awesome 6 Sharp";--fa-font-brands:normal 400 1em/1 "Font Awesome 6 Brands"}svg:not(:host).svg-inline--fa,svg:not(:root).svg-inline--fa{overflow:visible;box-sizing:content-box}.svg-inline--fa{display:var(--fa-display,inline-block);height:1em;overflow:visible;vertical-align:-.125em}.svg-inline--fa.fa-2xs{vertical-align:.1em}.svg-inline--fa.fa-xs{vertical-align:0}.svg-inline--fa.fa-sm{vertical-align:-.07143em}.svg-inline--fa.fa-lg{vertical-align:-.2em}.svg-inline--fa.fa-xl{vertical-align:-.25em}.svg-inline--fa.fa-2xl{vertical-align:-.3125em}.svg-inline--fa.fa-pull-left{margin-right:var(--fa-pull-margin,.3em);width:auto}.svg-inline--fa.fa-pull-right{margin-left:var(--fa-pull-margin,.3em);width:auto}.svg-inline--fa.fa-li{width:var(--fa-li-width,2em);top:.25em}.svg-inline--fa.fa-fw{width:var(--fa-fw-width,1.25em)}.fa-layers svg.svg-inline--fa{bottom:0;left:0;margin:auto;position:absolute;right:0;top:0}.fa-layers-counter,.fa-layers-text{display:inline-block;position:absolute;text-align:center}.fa-layers{display:inline-block;height:1em;position:relative;text-align:center;vertical-align:-.125em;width:1em}.fa-layers svg.svg-inline--fa{transform-origin:center center}.fa-layers-text{left:50%;top:50%;transform:translate(-50%,-50%);transform-origin:center center}.fa-layers-counter{background-color:var(--fa-counter-background-color,#ff253a);border-radius:var(--fa-counter-border-radius,1em);box-sizing:border-box;color:var(--fa-inverse,#fff);line-height:var(--fa-counter-line-height,1);max-width:var(--fa-counter-max-width,5em);min-width:var(--fa-counter-min-width,1.5em);overflow:hidden;padding:var(--fa-counter-padding,.25em .5em);right:var(--fa-right,0);text-overflow:ellipsis;top:var(--fa-top,0);transform:scale(var(--fa-counter-scale,.25));transform-origin:top right}.fa-layers-bottom-right{bottom:var(--fa-bottom,0);right:var(--fa-right,0);top:auto;transform:scale(var(--fa-layers-scale,.25));transform-origin:bottom right}.fa-layers-bottom-left{bottom:var(--fa-bottom,0);left:var(--fa-left,0);right:auto;top:auto;transform:scale(var(--fa-layers-scale,.25));transform-origin:bottom left}.fa-layers-top-right{top:var(--fa-top,0);right:var(--fa-right,0);transform:scale(var(--fa-layers-scale,.25));transform-origin:top right}.fa-layers-top-left{left:var(--fa-left,0);right:auto;top:var(--fa-top,0);transform:scale(var(--fa-layers-scale,.25));transform-origin:top left}.fa-1x{font-size:1em}.fa-2x{font-size:2em}.fa-3x{font-size:3em}.fa-4x{font-size:4em}.fa-5x{font-size:5em}.fa-6x{font-size:6em}.fa-7x{font-size:7em}.fa-8x{font-size:8em}.fa-9x{font-size:9em}.fa-10x{font-size:10em}.fa-2xs{font-size:.625em;line-height:.1em;vertical-align:.225em}.fa-xs{font-size:.75em;line-height:.08333em;vertical-align:.125em}.fa-sm{font-size:.875em;line-height:.07143em;vertical-align:.05357em}.fa-lg{font-size:1.25em;line-height:.05em;vertical-align:-.075em}.fa-xl{font-size:1.5em;line-height:.04167em;vertical-align:-.125em}.fa-2xl{font-size:2em;line-height:.03125em;vertical-align:-.1875em}.fa-fw{text-align:center;width:1.25em}.fa-ul{list-style-type:none;margin-left:var(--fa-li-margin,2.5em);padding-left:0}.fa-ul>li{position:relative}.fa-li{left:calc(var(--fa-li-width, 2em)*-1);position:absolute;text-align:center;width:var(--fa-li-width,2em);line-height:inherit}.fa-border{border-radius:var(--fa-border-radius,.1em);border:var(--fa-border-width,.08em) var(--fa-border-style,solid) var(--fa-border-color,#eee);padding:var(--fa-border-padding,.2em .25em .15em)}.fa-pull-left{float:left;margin-right:var(--fa-pull-margin,.3em)}.fa ...
# .vue-recycle-scroller{position:relative}.vue-recycle-scroller.direction-vertical:not(.page-mode){overflow-y:auto}.vue-recycle-scroller.direction-horizontal:not(.page-mode){overflow-x:auto}.vue-recycle-scroller.direction-horizontal{display:-webkit-box;display:-ms-flexbox;display:flex}.vue-recycle-scroller__slot{-webkit-box-flex:1;-ms-flex:auto 0 0px;flex:auto 0 0}.vue-recycle-scroller__item-wrapper{-webkit-box-flex:1;-ms-flex:1;flex:1;-webkit-box-sizing:border-box;box-sizing:border-box;overflow:hidden;position:relative}.vue-recycle-scroller.ready .vue-recycle-scroller__item-view{position:absolute;top:0;left:0;will-change:transform}.vue-recycle-scroller.direction-vertical .vue-recycle-scroller__item-wrapper{width:100%}.vue-recycle-scroller.direction-horizontal .vue-recycle-scroller__item-wrapper{height:100%}.vue-recycle-scroller.ready.direction-vertical .vue-recycle-scroller__item-view{width:100%}.vue-recycle-scroller.ready.direction-horizontal .vue-recycle-scroller__item-view{height:100%}.resize-observer[data-v-b329ee4c]{border:none;background-color:transparent;opacity:0}.resize-observer[data-v-b329ee4c],.resize-observer[data-v-b329ee4c] object{position:absolute;top:0;left:0;z-index:-1;width:100%;height:100%;pointer-events:none;display:block;overflow:hidden}
# body{overflow-x:hidden}ion-menu ion-content ion-toolbar,ion-popover ion-toolbar{--background:transparent!important}#app{position:relative;z-index:0}
# .navbar__button__link__item{text-transform:capitalize}.search-overlay{position:fixed;display:block;width:100vw;height:100vh;top:0;left:0;right:0;bottom:0;background-color:rgba(0,0,0,.5);cursor:pointer}.navbar{position:sticky;display:flex;background:#060d17;height:56px;width:100%;top:0;margin:0 auto;z-index:100}@media(max-width:1050px){.navbar{max-height:105px}}.navbar__wrapper{display:flex;justify-content:flex-end;width:100%;align-items:center;overflow:visible}@media(max-width:1050px){.navbar__wrapper{justify-content:center}}.navbar.navbar-hide{display:none!important}.navbar.bg-dark-brown{background:#141100}.navbar.landing-page{background:transparent}@media(min-width:1050px){.navbar.landing-page{height:86px;padding-top:15px;margin-bottom:-86px}.navbar.landing-page .navbar__logo img{width:219px}}@media(max-width:1050px){.navbar.landing-page{margin-bottom:0}}.navbar--hidden,.navbar.landing-page .landing-hide{display:none}.navbar--absolute{position:absolute}@media(max-width:1050px){.navbar{height:105px;align-items:flex-end}}@media(max-width:1050px){.navbar.navbar__button--watchlist a{color:var(--ion-color-primary)!important}}.navbar__logo{padding-inline-end:15px;display:flex;align-items:center;flex-shrink:0}.navbar__logo img{width:131px}@media(max-width:1050px){.navbar__logo{position:absolute;top:0;width:100%;min-height:46px;display:flex;justify-content:center;align-items:center;margin:0;padding-inline-end:0}}.navbar--is-mobile .navbar__logo{justify-content:left}.navbar--is-ios .navbar__logo{height:56px}.navbar__logo-link{display:flex;align-items:center}.navbar__logo .valentine-link{font-size:24px;margin-top:2px;margin-inline-start:8px}.navbar.container .navbar__logo{margin-inline-start:0;padding-inline-start:0}.navbar__search{z-index:1;flex-grow:2;height:52px;margin:0;margin-inline-end:7px;display:flex}.navbar__search .search-suggester .searchbar-input{color:#fff;box-shadow:none;border-radius:4px;font-size:15px;padding:4px 0;padding-inline-start:50px;padding-inline-end:15px}@media(max-width:992px){.navbar__search--expanded{left:0;right:0;position:absolute}}.navbar.landing-page .navbar__search{flex-grow:0;width:35em;transition:width .6s;transition-delay:.1s;align-items:center;display:flex}.navbar.landing-page .navbar__search:focus-within{width:100%}@media(max-width:1050px){.navbar.landing-page .navbar__search:focus-within{display:flex;align-items:center;justify-content:space-around}}.navbar__extra{display:flex;min-width:92px}@media(max-width:1050px){.navbar__extra{display:none}}.navbar__extra__small{display:none}@media(max-width:1050px){.navbar__extra__small{display:block;position:absolute;top:0;width:100%}[dir=ltr] .navbar__extra__small{right:0}[dir=rtl] .navbar__extra__small{left:0}.navbar__extra__small--left{display:flex;position:absolute}[dir=ltr] .navbar__extra__small--left{left:4px}[dir=rtl] .navbar__extra__small--left{right:4px}.navbar__extra__small--right{display:flex;position:absolute}[dir=ltr] .navbar__extra__small--right{right:0}[dir=rtl] .navbar__extra__small--right{left:0}}.navbar__extra--remove-spacing{min-width:unset}.navbar__button{height:56px;flex-grow:inherit;cursor:pointer}.navbar__button a{padding:0}.navbar__button>div,.navbar__button__link{justify-content:center}.navbar__button__link{display:flex;align-items:center;height:100%;white-space:nowrap;font-size:14px;color:#999c9f}.navbar__button__link.nav-link-active,.navbar__button__link.router-link-exact-active{font-weight:700;color:#d9e8ed!important}.navbar__button__link__item{margin:0 15px;display:flex;margin-inline-end:15px}@media(max-width:1050px){.navbar__button--home .navbar__button__link__item,.navbar__button--watchlist .navbar__button__link__item{display:none}}@media(max-width:1050px){.navbar__button--sports .navbar__button__link__item{margin:0 5px}}.navbar__button__icon{display:block}@media(min-width:1050px){.navbar__button__icon{margin:0 5px}}.navbar__button__icon.bookmark{display:none}@media(max-width:1050px){.navbar__button__icon.bookmark{display:bloc ...
# .freemium-filter__badge{display:inline-flex;align-items:center;font-size:14px;line-height:22px;letter-spacing:.2px;font-weight:700;text-align:center;color:#fff;background:linear-gradient(-225deg,#5c6374,#3b404e 31%,#272939 68%,#191d2a);padding:2px 7px;border-radius:4px;margin-inline-start:8px}.freemium-filter__badge--sm{padding:2px 6px;font-size:12px;line-height:16px}.freemium-filter__badge svg{margin-inline-end:8px}
# .search-suggester__results{overflow:auto;border-bottom-left-radius:8px;border-bottom-right-radius:8px;max-height:90vh;max-width:100vw}.search-suggester{position:relative}.search-suggester .sponsored-recommendation-search{margin-top:-10px;z-index:1000;position:relative;display:flex;width:100%}.search-suggester input[type=search]::-webkit-search-cancel-button{display:none}.search-suggester__results{z-index:200;padding:0 8px 8px;margin:-9px 0 0}.search-suggester__results--mobile{padding:0;margin:-11px -1em -.4em}.search-suggester--web{text-align:start;width:100%;padding:0;height:52px;z-index:10}.search-suggester--web ion-searchbar.ios{--background:#10161d;padding:8px;height:52px}.search-suggester--web .searchbar-cancel-button.sc-ion-searchbar-ios{background:#10161d;padding-inline-end:8px}.search-suggester__searchbar--mobile{padding-top:3px!important;padding-bottom:10px!important}.search-suggester__searchbar--mobile.md{height:52px;--background:#fff;--color:var(--ion-color-tertiary-shade)!important}.search-suggester__searchbar--mobile.md .searchbar-input{border-radius:4px!important}.search-suggester__searchbar input::-webkit-search-cancel-button{-webkit-appearance:none}.search-suggester__searchbar .searchbar-clear-icon{color:var(--ion-color-secondary)!important}.search-suggester__blocking{position:absolute;width:100%;padding:8px}.search-suggester__blocking__input{width:100%;height:38px;display:flex;align-items:center;background-color:var(--ion-color-tertiary-shade)}.searchbar-clear-button.sc-ion-searchbar-md{color:#fff!important}
# .logged-in[data-v-05cd4f88]{padding:0 15px;color:var(--ion-color-primary);font-size:18px}.logged-in[data-v-05cd4f88],.not-logged-in[data-v-05cd4f88]{height:100%;display:flex;align-items:center}@media(max-width:1050px){.not-logged-in__button[data-v-05cd4f88]{display:none}}.not-logged-in__icon[data-v-05cd4f88]{display:none;font-size:16px;cursor:pointer}@media(max-width:1050px){.not-logged-in__icon[data-v-05cd4f88]{display:block}}@media(max-width:1050px){.not-logged-in[data-v-05cd4f88]{padding:0 15px}}
# .basic-button{background:none;border:none;margin:0;padding:0;outline:none;white-space:nowrap;cursor:pointer}.basic-button__content{overflow:hidden;text-overflow:ellipsis;display:flex;align-items:center;justify-content:center}.basic-button.sm{font-size:13px;padding:.4rem 1.35rem}.basic-button.md{padding:.75rem 1.5rem}.basic-button.lg{font-size:18px;padding:1.6rem 4rem}.basic-button.lg.rounded{border-radius:8px}.basic-button.w-full{width:100%}.basic-button.rounded{border-radius:4px}.basic-button.uppercase{text-transform:uppercase}.basic-button.primary{font-weight:700;background-color:#fbc500;color:#000}.basic-button.primary.bg-none{color:#fbc500}.basic-button.primary.bg-none:hover{background-color:rgba(251,197,0,.1)}.basic-button.primary.border{color:#fbcb1a;border:1px solid #fbcb1a}.basic-button.primary.border:hover{background-color:rgba(251,197,0,.1)}.basic-button.primary:hover{background-color:#ddad00}.basic-button.secondary{color:#fff;font-weight:700;background-color:#4c5a67}.basic-button.secondary.bg-none{color:#4c5a67}.basic-button.secondary.bg-none:hover{background-color:rgba(94,107,118,.1)}.basic-button.secondary.border{border:1px solid #5e6b76}.basic-button.secondary.border:hover{background-color:rgba(94,107,118,.1)}.basic-button.secondary:hover{background-color:#ddad00}.basic-button.tertiary{color:#fff;background-color:#1c252f}.basic-button.tertiary.bg-none{color:#1c252f}.basic-button.tertiary.bg-none:hover{background-color:rgba(94,107,118,.1)}.basic-button.tertiary.border{border:1px solid #383d47}.basic-button.tertiary.border:hover{background-color:rgba(56,61,71,.1)}.basic-button.tertiary:hover{background-color:#383d47}.basic-button.light{color:#d9e8ed;background-color:#1c252f}.basic-button.light:hover{background-color:#383d47}.basic-button.medium{color:#fff;background-color:#8c8c8c}.basic-button.medium.border{color:#999c9f;border:1px solid #999c9f}.basic-button.medium.border:hover{background-color:rgba(153,156,159,.1)}.basic-button.medium:hover{background-color:#999c9f}.basic-button.bg-none{background:transparent}.basic-button.disabled{cursor:default;opacity:.5;pointer-events:none}
# .navbar__button__link[data-v-701c8f36]{background:none;border:none;outline:none;cursor:pointer}
# .login-menu-button__button[data-v-23236c2f]{all:unset;display:flex;align-items:center;height:100%;padding:0 15px;font-size:16px}.login-menu-button__button--logged-in[data-v-23236c2f]{color:var(--ion-color-primary)}
# html[data-v-45504e35]{scroll-padding-top:56px}@media screen and (max-width:1050px){html[data-v-45504e35]{scroll-padding-top:105px}}.popular-page__spinner[data-v-45504e35]{width:100%;height:50vh;display:flex;align-items:center;justify-content:center}.overlay-blocking-element[data-v-45504e35]{position:absolute;height:100vh;width:100vw}.content-provider-content[data-v-45504e35]{position:relative;width:100vw}.content-provider-content.full-height[data-v-45504e35]{min-height:100vh}.content-provider-content h1.section-title[data-v-45504e35]{font-size:32px}@media(max-width:599px){.content-provider-content .content-header[data-v-45504e35]{max-height:178px}.content-provider-content .content-header.content-header--expanded[data-v-45504e35]{max-height:none}}.content-provider-content.font-style-2 .section-title[data-v-45504e35]{font-family:Anton,Impact;letter-spacing:.64px!important;font-weight:400!important}.catalog-title[data-v-45504e35]{display:flex;align-items:center;justify-content:flex-start;width:100%}@media(max-width:1050px){.catalog-title h2[data-v-45504e35]{margin-inline-start:15px}}.show-filters[data-v-45504e35]{margin:0 15px}@media(max-width:599px){.show-filters__text[data-v-45504e35]{display:none}}.sponsored-recommendation[data-v-45504e35]{grid-area:double-poster;height:100%}@media(max-width:540px){.sponsored-recommendation[data-v-45504e35]{height:270px}}.list-options[data-v-45504e35]{display:flex;align-items:center;gap:24px;margin-bottom:16px}
# .content[data-v-d7672432]{min-height:100vh;display:flex;flex-direction:column;--padding-top:56px}@media(max-width:1050px){.content[data-v-d7672432]{--padding-top:105px}}
# .toggle-filters{display:flex;align-items:center;margin:10px}.toggle-filters__label{margin-inline-end:5px}.toggle-filters.border.bg-none{color:#d5d5d5}.content-container{display:flex;align-items:center;position:relative}.center-banner{display:flex;justify-content:center}.display-none{display:none}.content-header{min-height:138px;max-height:138px;overflow:hidden;position:relative;width:100%}@media(max-width:1050px){.content-header{padding-left:15px;padding-right:15px}}.content-header:hover{cursor:pointer}.content-header--expanded{max-height:none}.content-header--no-text{min-height:70px}.content-header--gradient{position:absolute;bottom:0;width:100%;text-align:center;margin:0;padding:15px 0;background-image:linear-gradient(180deg,rgba(6,13,23,0),var(--ion-background-color))}[dir=ltr] .content-header--gradient{left:0}[dir=rtl] .content-header--gradient{right:0}.content-header h1{padding-inline-end:15px}.content-header__search-heading{flex-grow:1;display:flex;align-items:center}@media(max-width:1050px){.content-header__search-heading{padding-left:15px;padding-right:15px}}.content-header__search-heading h1{font-size:24px;line-height:32px;font-weight:700;color:#d9e8ed}@media(max-width:767px){.content-header__search-heading h1{font-size:16px;line-height:24px}}.content-header__search-heading div{font-size:15px;padding:10px 0 5px}.content-header__caret{position:absolute;top:18px}[dir=ltr] .content-header__caret{right:0}[dir=rtl] .content-header__caret{left:0}@media(max-width:1050px){[dir=ltr] .content-header__caret{right:20px}[dir=rtl] .content-header__caret{left:20px}}
# .popover__filter{--ion-background-color:#10161d}.popover__filter .popover-content{width:400px}.filter-bar-seo{background-color:rgba(6,13,23,.8);background:linear-gradient(180deg,#060d17,rgba(6,13,23,.85));-webkit-backdrop-filter:blur(20px);backdrop-filter:blur(20px);position:relative;width:100%;z-index:10;transition:transform .3s ease-out}@media(max-width:1050px){.filter-bar-seo .row-filter-bar{margin:0 15px}}.filter-bar-seo__reset{margin-inline-start:auto}.filter-bar-seo__popover{transform:translateY(50px)}@media(min-width:992px){.filter-bar-seo__filter-button{display:none}}@media(max-width:992px){.filter-bar-seo__filter-button{display:block}}.filter-bar-seo__additional{position:relative;padding-bottom:10px;display:flex;align-items:baseline;justify-content:flex-start}.filter-bar-seo__additional>div:not(:last-child){margin-inline-end:10px}.filter-bar-seo__additional__heading{white-space:nowrap;color:var(--ion-color-secondary);text-transform:uppercase;font-weight:700}.filter-bar-seo__additional .jw-chip-button{margin-bottom:0}.filter-bar-seo__additional .hidden-horizontal-scrollbar__items{margin:0!important;bottom:0!important}.filter-bar-seo__additional--long:not(:last-child){margin-inline-end:4px}@media(max-width:992px){.filter-bar-seo__additional--long{display:none}.filter-bar-seo__additional--long.always-active{display:block!important}}.filter-bar-seo a{transition:opacity .2s ease;cursor:pointer}.filter-bar-seo--inactive a{opacity:.4}.filter-bar-seo--hidden{transform:translateY(-180px)}
# .filter-bar-seo__provider-row{margin-bottom:5px}.filter-bar-seo__provider-icon{display:inline-block;width:50px;height:50px;opacity:.25;margin:10px 5px;transition:opacity .2s ease-in-out;cursor:pointer}.filter-bar-seo__provider-icon button{all:unset}.filter-bar-seo__provider-icon img{width:100%}.filter-bar-seo__provider-icon:first-child{margin-inline-start:0}.filter-bar-seo__provider-icon.active{opacity:1}.filter-bar-seo__provider-icon.disabled{opacity:.25;filter:grayscale(100%);pointer-events:none}
# .provider-icon,.provider-icon img{border-radius:20%}.provider-icon--labelled{overflow:hidden;height:100%;display:flex;justify-content:center;align-items:center;font-size:1.2rem}.provider-icon--labelled.timeline__provider-block__logo{font-size:.7rem}.provider-icon .ribbon{position:absolute;top:6px;right:-10px;width:100%;text-align:center;background-color:#d5d5d5;color:#1c252f;font-size:9px;font-weight:700;padding:0 4px;border-radius:0 0 0 5px;z-index:1;transform:rotate(45deg)}
# .hidden-horizontal-scrollbar{overflow:hidden;display:flex;position:relative}.hidden-horizontal-scrollbar__items{overflow-x:auto;scrollbar-width:none;-webkit-overflow-scrolling:touch;-ms-overflow-style:-ms-autohiding-scrollbar;position:relative;flex-wrap:nowrap;display:flex;align-items:center}.hidden-horizontal-scrollbar__items::-webkit-scrollbar{display:none}.hidden-horizontal-scrollbar__items>*{flex:0 0 auto}.hidden-horizontal-scrollbar__items.shift-scrollbar{margin-inline-start:-46px}@media(max-width:380px){.hidden-horizontal-scrollbar__items.shift-scrollbar{margin-inline-start:-26px}}.hidden-horizontal-scrollbar__items--faded-end{-webkit-mask-image:linear-gradient(90deg,#060d17 90%,transparent);mask-image:linear-gradient(90deg,#060d17 90%,transparent)}.hidden-horizontal-scrollbar__items--faded-start{-webkit-mask-image:linear-gradient(90deg,transparent 0,#060d17 5%);mask-image:linear-gradient(90deg,transparent 0,#060d17 5%)}.hidden-horizontal-scrollbar__items--faded{-webkit-mask-image:linear-gradient(270deg,transparent 0,#060d17 5%,#060d17 95%,transparent);mask-image:linear-gradient(270deg,transparent 0,#060d17 5%,#060d17 95%,transparent)}.hidden-horizontal-scrollbar__nav{background:rgba(6,13,23,.8);cursor:pointer;position:absolute;top:0;height:100%;width:40px;display:none;font-size:25px;justify-content:center;align-items:center;z-index:30}[dir=ltr] .hidden-horizontal-scrollbar__nav--end{right:0}[dir=ltr] .hidden-horizontal-scrollbar__nav--start,[dir=rtl] .hidden-horizontal-scrollbar__nav--end{left:0}[dir=rtl] .hidden-horizontal-scrollbar__nav--start{right:0}@media(pointer:fine){.hidden-horizontal-scrollbar:hover .hidden-horizontal-scrollbar__nav{display:flex!important}}@media(max-width:767px){.hidden-horizontal-scrollbar{margin-left:-15px;margin-right:-15px}.hidden-horizontal-scrollbar__items{padding-left:15px;padding-right:15px}}
# .filter-bar-content-type-seo{display:flex}.filter-bar-content-type-seo.border-bottom{border-bottom:1px solid #212121}
# .filter-bar-content-type__item{position:relative;margin-inline-end:16px}.filter-bar-content-type__item:last-of-type{margin-inline-end:0}.filter-bar-content-type__item:after{content:"";max-width:40px;width:100%;display:block;border-bottom:3px solid #fbc500;transform:scaleX(0);transition:transform .25s ease-in-out}[dir=ltr] .filter-bar-content-type__item:after{transform-origin:0 50%}[dir=rtl] .filter-bar-content-type__item:after{transform-origin:100% 50%}.filter-bar-content-type__item>*{white-space:nowrap;font-size:20px;font-weight:900;color:#8c8c8c;transition:color .1s ease-in-out;transition-delay:.2s;cursor:pointer}.filter-bar-content-type__item:not(.active)>:hover{color:#d5d5d5}.filter-bar-content-type__item.active:after{transform:scaleX(1)}.filter-bar-content-type__item.active>*{color:#fff!important}
# .chip-button{white-space:nowrap;border:1px solid transparent;border-radius:4px;background-color:transparent;transition:background-color .1s linear}.chip-button button{border:none;background:none}.chip-button.no-borders{border:0}.chip-button a,.chip-button button{display:block;font-weight:400;font-size:15px;padding:5px 10px;color:#b9bdcc;text-overflow:ellipsis;overflow:hidden;cursor:pointer}.chip-button.active{background-color:#434f5b;color:#fff}.chip-button.active a,.chip-button.active button{color:#fff}.chip-button:last-child{border-inline-end-width:1px;margin-inline-end:0}
# .filter-bar__reset-button[data-v-eff7fc82]{display:flex;align-items:center}.filter-bar__reset-button span[data-v-eff7fc82]{display:flex}.filter-bar__reset-button__text[data-v-eff7fc82]{font-weight:700;margin-inline-start:4px}@media(max-width:480px){.filter-bar__reset-button__text[data-v-eff7fc82]{display:none!important}}
# .title-list--is-empty{display:flex;flex-direction:column;justify-content:center;padding:4%}
# .title-list-options[data-v-0c6fdafa]{position:relative;min-height:36px;white-space:nowrap}@media(max-width:1050px){.title-list-options[data-v-0c6fdafa]{margin-left:15px}}.title-list-options__box[data-v-0c6fdafa]{display:flex;justify-content:space-between;align-items:center;padding:0}.title-list-options__box-left[data-v-0c6fdafa]{display:flex;align-items:center;max-width:70vw}.title-list-options__box-right[data-v-0c6fdafa]{display:flex;align-items:center;color:var(--ion-color-secondary)!important;text-align:end}.title-list-options__box-view[data-v-0c6fdafa]{display:none}@media(min-width:992px){.title-list-options__box-view[data-v-0c6fdafa]{display:block}}.title-list-options__box-btns[data-v-0c6fdafa]{display:flex;align-items:center;margin-inline-start:16px}.title-list-options__box-btns .button[data-v-0c6fdafa]:last-child{--padding-end:0}
# .total-titles-seo{color:#b9bdcc;margin:8px 0;margin-inline-end:8px}
# .title-list-sorting-switcher{color:#b9bdcc!important;overflow:hidden;text-overflow:ellipsis;white-space:nowrap;cursor:pointer}.title-list-sorting-switcher__label{margin-inline-end:1px}@media(max-width:320px){.title-list-sorting-switcher__label{display:none}}.title-list-sorting-switch-action-sheet .action-sheet-premium-disabled{opacity:.6}
# .title-list-grid{display:grid;grid-template-columns:repeat(auto-fill,minmax(170px,1fr));grid-gap:15px}@media(max-width:1050px){.title-list-grid{padding-left:15px;padding-right:15px}}.title-list-grid .sponsored-recommendation{grid-row-start:1;grid-column:span 2}.title-list-grid .sponsored-recommendation--hidden{display:none}@media(max-width:311px){.title-list-grid .sponsored-recommendation{grid-column:1}}@media(max-width:767px){.title-list-grid{grid-template-columns:repeat(auto-fill,minmax(160px,1fr))}}@media(max-width:380px){.title-list-grid{grid-template-columns:repeat(auto-fill,minmax(136px,1fr));grid-gap:10px}}.pointer-none{pointer-events:none}
# .spinner[data-v-42a39cb8]{width:100%;position:absolute;left:0}.spinner.top[data-v-42a39cb8]{transform:translateY(-10px)}.spinner.bottom[data-v-42a39cb8]{transform:translateY(-35px)}.scrollable-area[data-v-42a39cb8]{width:100%}.scrollable-area--top[data-v-42a39cb8]{height:20px}.pagination-container[data-v-42a39cb8]{position:absolute;margin:45px 15px 15px;width:calc(100% - 30px);max-width:1624px}@media(min-width:1050px){.pagination-container[data-v-42a39cb8]{width:calc(100% - 130px);margin-left:0;margin-right:0}}
# .poster-link{all:unset;width:100%;display:block;cursor:pointer}
# ...
#           <a data-v-7c31ac2a="" href="/in/tv-show/sweet-home/season-3">
#            Sweet Home Season 3
#           </a>
#          </li>
#          <li class="jw-app-footer__link" data-v-7c31ac2a="">
#           <a data-v-7c31ac2a="" href="/in/tv-show/cobra-kai/season-6">
#            Cobra Kai Season 6
#           </a>
#          </li>
#          <li class="jw-app-footer__link" data-v-7c31ac2a="">
#           <a data-v-7c31ac2a="" href="/in/tv-show/morangos-com-acucar/season-3">
#            Morangos com Açúcar Season 3
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div data-v-7c31ac2a="">
#         <h5 data-v-7c31ac2a="">
#          <a data-v-7c31ac2a="" href="/in/guide">
#           Top 5 latest news
#          </a>
#         </h5>
#         <ul class="list-unstyled top-articles" data-v-7c31ac2a="">
#          <li class="jw-app-footer__link" data-v-7c31ac2a="">
#           <a data-v-7c31ac2a="" href="/in/guide/movies-and-shows-like-teri-baaton-mein-aisa-uljha-jiya">
#            10 Movies and Shows to Watch If You Loved Teri Baaton Mein Aisa Uljha Jiya (and Where to Stream Them)
#           </a>
#          </li>
#          <li class="jw-app-footer__link" data-v-7c31ac2a="">
#           <a data-v-7c31ac2a="" href="/in/guide/movies-and-tv-shows-like-shaitaan">
#            10 Movies and Shows to Watch If You Loved Shaitaan (and Where to Stream Them)
#           </a>
#          </li>
#          <li class="jw-app-footer__link" data-v-7c31ac2a="">
#           <a data-v-7c31ac2a="" href="/in/guide/best-romantic-bollywood-movies-90s">
#            The 10 Best Romantic Bollywood Movies of the 1990s
#           </a>
#          </li>
#          <li class="jw-app-footer__link" data-v-7c31ac2a="">
#           <a data-v-7c31ac2a="" href="/in/guide/best-arshad-warsi-movies">
#            30 Best Arshad Warsi Movies and Where to Watch Them
#           </a>
#          </li>
#          <li class="jw-app-footer__link" data-v-7c31ac2a="">
#           <a data-v-7c31ac2a="" href="/in/guide/best-dharmendra-movies">
#            50 Best Dharmendra Movies and Where to Watch Them
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </footer>
#      <!-- -->
#     </div>
#    </div>
#    <style>
#     null
#    </style>
#    <div>
#     <!-- -->
#     <!-- -->
#     <!-- -->
#     <!-- -->
#     <!-- -->
#     <!-- -->
#    </div>
#   </div>
#   <script data-vue-ssr-data="">
#    window.__DATA__={"state":{"app":{"geoLocation":"us","seoUser":true,"jwSession":null,"jwSessionExpires":null},"constant":{"providers":[{"clearName":"Netflix","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F207360008\u002F{profile}\u002Fnetflix.{format}","monetizationTypes":["FLATRATE"],"packageId":8,"selected":false,"shortName":"nfx","slug":"netflix","technicalName":"netflix"},{"clearName":"Amazon Prime Video","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F52449861\u002F{profile}\u002Famazonprimevideo.{format}","monetizationTypes":["FLATRATE"],"packageId":119,"selected":false,"shortName":"prv","slug":"amazon-prime-video","technicalName":"amazonprimevideo"},{"clearName":"Apple TV Plus","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F152862153\u002F{profile}\u002Fappletvplus.{format}","monetizationTypes":["FLATRATE"],"packageId":350,"selected":false,"shortName":"atp","slug":"apple-tv-plus","technicalName":"appletvplus"},{"clearName":"Apple TV","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F190848813\u002F{profile}\u002Fitunes.{format}","monetizationTypes":["BUY","RENT"],"packageId":2,"selected":false,"shortName":"itu","slug":"apple-tv","technicalName":"itunes"},{"clearName":"Crunchyroll","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F127445869\u002F{profile}\u002Fcrunchyroll.{format}","monetizationTypes":["ADS","FLATRATE"],"packageId":283,"selected":false,"shortName":"cru","slug":"crunchyroll","technicalName":"crunchyroll"},{"clearName":"Hotstar","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F240029443\u002F{profile}\u002Fhotstar.{format}","monetizationTypes":["FLATRATE"],"packageId":122,"selected":false,"shortName":"hst","slug":"hotstar","technicalName":"hotstar"},{"clearName":"Jio Cinema","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F312325227\u002F{profile}\u002Fjiocinema.{format}","monetizationTypes":["FLATRATE"],"packageId":220,"selected":false,"shortName":"jio","slug":"jio-cinema","technicalName":"jiocinema"},{"clearName":"Zee5","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F93795879\u002F{profile}\u002Fzee5.{format}","monetizationTypes":["ADS","FLATRATE","FREE"],"packageId":232,"selected":false,"shortName":"zee","slug":"zee5","technicalName":"zee5"},{"clearName":"Eros Now","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F247912837\u002F{profile}\u002Ferosnow.{format}","monetizationTypes":["FLATRATE"],"packageId":218,"selected":false,"shortName":"ern","slug":"eros-now","technicalName":"erosnow"},{"clearName":"MLS Season Pass","hasSport":true,"hasTitles":false,"icon":"\u002Ficon\u002F303372959\u002F{profile}\u002Fmlsseasonpass.{format}","monetizationTypes":["FLATRATE"],"packageId":1851,"selected":false,"shortName":"mls","slug":"mls-season-pass","technicalName":"mlsseasonpass"},{"clearName":"Google Play Movies","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F169478387\u002F{profile}\u002Fplay.{format}","monetizationTypes":["BUY","RENT"],"packageId":3,"selected":false,"shortName":"ply","slug":"google-play-movies","technicalName":"play"},{"clearName":"MUBI","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F164970114\u002F{profile}\u002Fmubi.{format}","monetizationTypes":["FLATRATE","RENT"],"packageId":11,"selected":false,"shortName":"mbi","slug":"mubi","technicalName":"mubi"},{"clearName":"Sony Liv","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F207468084\u002F{profile}\u002Fsonyliv.{format}","monetizationTypes":["ADS","FLATRATE"],"packageId":237,"selected":false,"shortName":"snl","slug":"sony-liv","technicalName":"sonyliv"},{"clearName":"YouTube","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F59562423\u002F{profile}\u002Fyoutube.{format}","monetizationTypes":["BUY","FLATRATE","RENT"],"packageId":192,"selected":false,"shortName":"yot","slug":"youtube","technicalName":"youtube"},{"clearName":"GuideDoc","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F2625277\u002F{profile}\u002Fguidedoc.{f ...
#   </script>
#   <script>
#    window.__APOLLO_STATE__={"defaultClient":{"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).0":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).1":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).2":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).3":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).4":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).5":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).6":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).7":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).8":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).9":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).10":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).11":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).12":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).13":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY":{"ageCertifications({\"country\":\"IN\"})":[{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).0","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).1","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).2","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).3","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).4","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).5","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).6","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).7","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).8","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).9","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).10","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).11","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).12","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).13","typename":"AgeCertification"}],"ageCertifications({\"country\":\"IN\",\"objectType\":\"MOVIE\"})":[{"type":"id","generated":false,"id":"AgeCertification:27","typename":"AgeCertification"},{"type":"id","generated":false,"id":"AgeCertification:28","typename":"AgeCertification"},{"type":"id","generated":false,"id":"AgeCertification:29","typename":"AgeCertification"},{"type":"id","generated":false,"id":"AgeCertification:21388","typename":"AgeCertification"},{"type":"id","generated":false,"id":"AgeCertification:21405","typename":"AgeCertification"},{"type":"id","generated":false,"id":"AgeCertification:21427","typename":"AgeCertification"},{"type":"id","generated":false ...
#   </script>
#   <script>
#    // Runtime Env Vars
# 			window.DNS_PREFETCH=[{"rel":"dns-prefetch","href":"https://www.googletagmanager.com/"},{"rel":"dns-prefetch","href":"https://ib.adnxs.com"}];
# 			window.HTTP_PRECONNECT=[{"rel":"preconnect","crossorigin":"use-credentials","href":"https://images.justwatch.com"}];
# 			window.BUILD_CONFIG={"appVersion":"3.8.2","commitHash":"ee36d8799811f85b6c8a35a7aefbbba48b77a1f7","commitShortHash":"ee36d87","env":"prod","globals":{"ASSETS_DIR":"appassets","BUILD_TARGET":"SSR","IS_BUILD":true,"IS_SERVE":false,"IS_START":false,"IS_DEV":true,"IS_PROD":false}};
# 			window.JW_CONFIG={"API":"https://apis.justwatch.com/content","ASSETS_URL":"https://www.justwatch.com/static/compile_jw/assets","BRAZE_BASE_URL":"sdk.iad-05.braze.com","BRAZE_WEB_API_KEY":"1aad19f0-6f9f-4fd5-9a05-9ca5499795f9","CHECKIP_URL":"https://info.justwatch.com ","CLICK_URL":"https://click.justwatch.com","DISCOVERY_URL":"https://apis.justwatch.com/discovery","DOMAIN":"justwatch.com","EVENT_URL":"https://apis.justwatch.com/event","EXPERIMENT_CONFIG_URL":"https://apis.justwatch.com/configuration/experiments","FACEBOOK_APP_ID":"794243977319785","FEEDBACK_URL":"https://apis.justwatch.com/feedback","FIREBASE_API_KEY":"AIzaSyDv6JIzdDvbTBS-JWdR4Kl22UvgWGAyuo8","FIREBASE_APP_ID":"1:413470318987:web:28b910bbf217d7d5034f8e","FIREBASE_AUTH_DOMAIN":"accounts.justwatch.com","FIREBASE_MESSAGING_SENDER_ID":"413470318987","FIREBASE_PROJECT_ID":"justwatch-apps-beta","FIREBASE_STORAGE_BUCKET":"justwatch-apps-beta.appspot.com","GOOGLE_CLIENT_ID":"532718895899-fhbuhnd9nsrae0ivadejq35vsr2sgr0l.apps.googleusercontent.com","GOOGLE_MAPS_API_KEY":"AIzaSyBVU86Zuf3v_6W8dnnV9BRKe_YSBXroqCA","GRAPHQL_URL":"https://apis.justwatch.com/graphql","IDENTITY_URL":"https://apis.justwatch.com/identity","ID_URL":"https://i.tw.cx","IMAGESCALER_FAST_URL":"https://www.justwatch.com/images","IMAGESCALER_URL":"https://images.justwatch.com","JOBSITE_URL":"https://www.justwatch.com/talent/jobs","ITUNES_APP_ID":"979227482","NOTIFICATION_URL":"https://apis.justwatch.com/notification","PLOT_RECOMMENDER_URL":"https://apis.justwatch.com/plotpoint","REVENUE_CAT_API_URL":"https://api.revenuecat.com/v1","REVENUE_CAT_PUBLIC_KEY":"sijZLciaBRrTwuIAeBkAqzQNtMNQaXqV","SENTRY_DSN":"https://ad6b9c4b3a3f4e998e38c3c7ed92574f@sentry.justwatch.com/4","SENTRY_DSN_SSR_CLIENT":"https://e83b625f73464fe9af5aea210630233c@sentry.justwatch.com/9","SNOWPLOW_COLLECTOR_ENDPOINT":"sp.justwatch.com","USER_URL":"https://userapi.justwatch.com","WRITE_URL":"https://apis.justwatch.com/personalization","AD_TAG":"https://pubads.g.doubleclick.net/gampad/ads?iu=/21679119891/video_ads_trailers&description_url=https%3A%2F%2Fwww.justwatch.com%2F&tfcd=0&npa=0&sz=640x360%7C640x480&gdfp_req=1&output=vast&unviewed_position_start=1&env=vp&impl=s&correlator=&vad_type=linear","ZENDESK_SUBDOMAIN":"https://justwatch.zendesk.com","SUBSCRIPTIONS":{"regular":{"id":"prod_LKEY8MLBOZwwQN","priceId":"price_1Kda5MKD0TTmBHo0KnyileCK","type":"regular","timeframe":"monthly","price":2.49},"yearly":{"id":"prod_NzlZqI8lGP1soA","priceId":"price_1NDm2ZKD0TTmBHo0u99J14yr","type":"yearly","timeframe":"yearly","price":19.99},"monthly":{"id":"prod_NzlSDe5AXBSi4X","priceId":"price_1NDlvNKD0TTmBHo08pBWfjIZ","type":"monthly","timeframe":"monthly","price":3.99},"onetime":{"id":"prod_NzlbbPqyeBPsT8","priceId":"price_1NDm4CKD0TTmBHo0KnsX1AJw","type":"onetime","timeframe":"one time","price":59.99}}};
# 			window.IMG_POSTER_LOAD_COUNT=4;
# 			window.IMG_PROVIDERS_BAR_LOAD_COUNT=7;
# 			window.IMG_PROVIDERS_BUY_BOX_COUNT=6;
# 			window.IMG_NEW_TIMELINE_ROWS=1;
# 			window.IS_CANARY=false;
# 			window.NEW_TIMELINE_BUCKETS_LIMIT=4;
# 			window.NEW_TIMELINE_TITLES_PER_BUCKET_LIMIT=10;
# 			window.VUE_APP_TESTS_E2E=false;
#   </script>
#   <script defer="" src="/appassets/js/1715863991816_runtime.6bbad7e5.js">
#   </script>
#   <script defer="" src="/appassets/js/1715863991816_popular.7b204317.js">
#   </script>
#   <script defer="" src="/appassets/js/1715863991816_chunk-345d0258.6b63a485.js">
#   </script>
#   <script defer="" src="/appassets/js/1715863991816_chunk-53be1cd7.d28066d1.js">
#   </script>
#   <script defer="" src="/appassets/js/1715863991816_title-list-grid.e98fe605.js">
#   </script>
#   <script defer="" src="/appassets/js/1715863991816_chunk-09eadbc1.f56ec8a2.js">
#   </script>
#   <script defer="" src="/appassets/js/1715863991816_chunk-b8461cac.fe2ef292.js">
#   </script>
#   <script defer="" src="/appassets/js/1715863991816_default-footer.8680e601.js">
#   </script>
#   <script defer="" src="/appassets/js/1715863991816_low-priority-components.90948146.js">
#   </script>
#   <script defer="" src="/appassets/js/1715863991816_npm.vue.53092bae.js">
#   </script>
#   <script defer="" src="/appassets/js/1715863991816_npm.vue-router.3d04e099.js">
#   </script>
#   <script defer="" src="/appassets/js/1715863991816_npm.firebase.3638ea87.js">
#   </script>
#   <script defer="" src="/appassets/js/1715863991816_npm.sentry.911ad572.js">
#   </script>
#   <script defer="" src="/appassets/js/1715863991816_npm.sentry-internal.e001ff88.js">
#   </script>
#   <script defer="" src="/appassets/js/1715863991816_npm.graphql.f600a27c.js">
#   </script>
#   <script defer="" src="/appassets/js/1715863991816_npm.fortawesome.bf92b8fd.js">
#   </script>
#   <script defer="" src="/appassets/js/1715863991816_npm.apollo-client.25b9e10b.js">
#   </script>
#   <script defer="" src="/appassets/js/1715863991816_npm.localforage.67c908d6.js">
#   </script>
#   <script defer="" src="/appassets/js/1715863991816_app.c15d5d94.js">
#   </script>
#  </body>
#  <script nomodule="">
#   window.IS_LEGACY = true;
#  </script>
#  <script type="module">
#   window.IS_LEGACY = false;
#  </script>
# </html>

# %% [markdown]
# ## **Fetching Tv shows Url details**

# %%
# Write Your Code here
# Finding all tv_show_elements with the specified class
tv_show_elements = soup.find_all('a', {'class':'title-list-grid__item--link'})

# Initializing an empty list to store the tvshow URLs
tvshow_urls = []

# Loop through each tv_show_element and extract the 'href' attribute
for tv_show_element in tv_show_elements:
  href_value = tv_show_element.get('href')
  full_url = f'https://www.justwatch.com{href_value}'
  tvshow_urls.append(full_url)

# Printing the list of tvshow URLs
print(tvshow_urls)
# Out:
# ['https://www.justwatch.com/in/tv-show/shogun-2024', 'https://www.justwatch.com/in/tv-show/heeramandi', 'https://www.justwatch.com/in/tv-show/panchayat', 'https://www.justwatch.com/in/tv-show/fallout', 'https://www.justwatch.com/in/tv-show/mirzapur', 'https://www.justwatch.com/in/tv-show/game-of-thrones', 'https://www.justwatch.com/in/tv-show/3-body-problem', 'https://www.justwatch.com/in/tv-show/dead-boy-detectives', 'https://www.justwatch.com/in/tv-show/baby-reindeer', 'https://www.justwatch.com/in/tv-show/apharan', 'https://www.justwatch.com/in/tv-show/young-sheldon', 'https://www.justwatch.com/in/tv-show/attack-on-titan', 'https://www.justwatch.com/in/tv-show/inspector-rishi', 'https://www.justwatch.com/in/tv-show/sunflower-2021', 'https://www.justwatch.com/in/tv-show/the-walking-dead', 'https://www.justwatch.com/in/tv-show/murder-in-mahim', 'https://www.justwatch.com/in/tv-show/aashram', 'https://www.justwatch.com/in/tv-show/lucifer', 'https://www.justwatch.com/in/tv-show/farzi', 'https://www.justwatch.com/in/tv-show/a-gentleman-in-moscow', 'https://www.justwatch.com/in/tv-show/mastram', 'https://www.justwatch.com/in/tv-show/untitled-kapil-sharma-netflix-project', 'https://www.justwatch.com/in/tv-show/solo-leveling-2024', 'https://www.justwatch.com/in/tv-show/dil-dosti-dilemma', 'https://www.justwatch.com/in/tv-show/thank-you-next', 'https://www.justwatch.com/in/tv-show/we-were-the-lucky-ones', 'https://www.justwatch.com/in/tv-show/ranneeti-balakot-and-beyond', 'https://www.justwatch.com/in/tv-show/the-gentlemen', 'https://www.justwatch.com/in/tv-show/ripley', 'https://www.justwatch.com/in/tv-show/broken-but-beautiful', 'https://www.justwatch.com/in/tv-show/queen-of-tears', 'https://www.justwatch.com/in/tv-show/the-family-man', 'https://www.justwatch.com/in/tv-show/gandii-baat', 'https://www.justwatch.com/in/tv-show/the-rookie', 'https://www.justwatch.com/in/tv-show/dark-matter-2024', 'https://www.justwatch.com/in/tv-show/house-of-the-dragon', 'https://www.justwatch.com/in/tv-show/asur', 'https://www.justwatch.com/in/tv-show/jujutsu-kaisen', 'https://www.justwatch.com/in/tv-show/goodbye-earth', 'https://www.justwatch.com/in/tv-show/true-detective', 'https://www.justwatch.com/in/tv-show/euphoria', 'https://www.justwatch.com/in/tv-show/maamla-legal-hai', 'https://www.justwatch.com/in/tv-show/modern-family', 'https://www.justwatch.com/in/tv-show/dehati-ladke', 'https://www.justwatch.com/in/tv-show/the-last-of-us', 'https://www.justwatch.com/in/tv-show/jack-reacher', 'https://www.justwatch.com/in/tv-show/maharani-2021', 'https://www.justwatch.com/in/tv-show/demon-slayer-kimetsu-no-yaiba', 'https://www.justwatch.com/in/tv-show/house', 'https://www.justwatch.com/in/tv-show/stranger-things', 'https://www.justwatch.com/in/tv-show/maxton-hall-the-world-between-us', 'https://www.justwatch.com/in/tv-show/paperhouse', 'https://www.justwatch.com/in/tv-show/naruto-shippuden', 'https://www.justwatch.com/in/tv-show/peaky-blinders', 'https://www.justwatch.com/in/tv-show/naruto', 'https://www.justwatch.com/in/tv-show/brigands-the-quest-for-gold', 'https://www.justwatch.com/in/tv-show/the-good-doctor', 'https://www.justwatch.com/in/tv-show/the-flash', 'https://www.justwatch.com/in/tv-show/undekhi', 'https://www.justwatch.com/in/tv-show/mtv-splitsvilla', 'https://www.justwatch.com/in/tv-show/invincible', 'https://www.justwatch.com/in/tv-show/dark-desire', 'https://www.justwatch.com/in/tv-show/how-i-met-your-mother', 'https://www.justwatch.com/in/tv-show/scam-1992', 'https://www.justwatch.com/in/tv-show/gullak', 'https://www.justwatch.com/in/tv-show/breaking-bad', 'https://www.justwatch.com/in/tv-show/yellowstone', 'https://www.justwatch.com/in/tv-show/bridgerton', 'https://www.justwatch.com/in/tv-show/one-punch-man', 'https://www.justwatch.com/in/tv-show/monk', 'https://www.justwatch.com/in/tv-show/x-men-97', 'https://www.justwatch.com/in/tv-show/damaged', 'https://www.justwatch.com/in/tv-show/lootere', 'https://www.justwatch.com/in/tv-show/ ...

# %% [markdown]
# ## **Fetching Tv Show Title details**

# %%
# Write Your Code here
# Initializing an empty list to store TV show titles
tvshow_title = []

# Iterating through each anchor element in the anchor_elements list
for tv_show_element in tv_show_elements:
    # Extracting the last part of the href attribute (the TV show title) and stripping whitespace
    name = tv_show_element.get('href').split('/')[-1].strip()

    # Appending the extracted and stripped TV show title to the tvshow_title list
    tvshow_title.append(name)

# Printing the list containing TV show titles
print(tvshow_title)
# Out:
# ['shogun-2024', 'heeramandi', 'panchayat', 'fallout', 'mirzapur', 'game-of-thrones', '3-body-problem', 'dead-boy-detectives', 'baby-reindeer', 'apharan', 'young-sheldon', 'attack-on-titan', 'inspector-rishi', 'sunflower-2021', 'the-walking-dead', 'murder-in-mahim', 'aashram', 'lucifer', 'farzi', 'a-gentleman-in-moscow', 'mastram', 'untitled-kapil-sharma-netflix-project', 'solo-leveling-2024', 'dil-dosti-dilemma', 'thank-you-next', 'we-were-the-lucky-ones', 'ranneeti-balakot-and-beyond', 'the-gentlemen', 'ripley', 'broken-but-beautiful', 'queen-of-tears', 'the-family-man', 'gandii-baat', 'the-rookie', 'dark-matter-2024', 'house-of-the-dragon', 'asur', 'jujutsu-kaisen', 'goodbye-earth', 'true-detective', 'euphoria', 'maamla-legal-hai', 'modern-family', 'dehati-ladke', 'the-last-of-us', 'jack-reacher', 'maharani-2021', 'demon-slayer-kimetsu-no-yaiba', 'house', 'stranger-things', 'maxton-hall-the-world-between-us', 'paperhouse', 'naruto-shippuden', 'peaky-blinders', 'naruto', 'brigands-the-quest-for-gold', 'the-good-doctor', 'the-flash', 'undekhi', 'mtv-splitsvilla', 'invincible', 'dark-desire', 'how-i-met-your-mother', 'scam-1992', 'gullak', 'breaking-bad', 'yellowstone', 'bridgerton', 'one-punch-man', 'monk', 'x-men-97', 'damaged', 'lootere', 'dr-arora', 'the-atypical-family', 'them', 'loki', 'the-boys', 'greys-anatomy', 'bodkin', 'playground', 'college-romance', 'doctor-who', 'the-goat', 'maigret', '9-1-1', 'taaza-khabar', 'sugar', 'the-railway-men-the-untold-story-of-bhopal-1984', 'death-note', 'better-call-saul', 'under-the-dome', 'paatal-lok', 'spartacus', 'adrishyam-the-invisible-heroes', 'kaiju-no-8', 'wednesday', 'you', 'lost', 'sarkaar']

# %% [markdown]
# ## **Fetching Release Year**

# %%
# Write Your Code here
# Initializing an empty list to store TV show release years
tvshow_release_year = []

# Iterating through each TV show URL
for url in tvshow_urls:
    # Fetching the webpage content for the current TV show URL
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    # Finding the span element with class 'text-muted'
    year = soup.find('span', {'class':'text-muted'})

    # Extracting the release year from the text content of the span element
    # If the span element is not found, set release year to 'NA'
    tvshow_release_year.append(year.text.split("(")[-1].split(")")[0] if year else 'NA')

# Printing the list containing TV show release years
print(tvshow_release_year)
# Out:
# ['2024', '2024', '2020', '2024', '2018', '2011', '2024', '2024', '2024', '2018', '2017', '2013', '2024', '2021', '2010', '2024', '2020', '2016', '2023', '2024', '2020', '2024', '2024', '2024', '2024', '2024', '2024', '2024', '2024', '2018', '2024', '2019', '2018', '2018', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '2017', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '2021', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '2018', 'NA', 'NA']

# %% [markdown]
# ## **Fetching TV Show Genre Details**

# %%
# Initializing an empty list to store TV show genres
tvshow_genres = []

# Iterating through each TV show URL
for url in tvshow_urls:
  page = requests.get(url)

  # Creating a BeautifulSoup object to parse the HTML content
  soup = BeautifulSoup(page.text, 'html.parser')

  # Finding the h3 element with class 'detail-infos__subheading' and text 'Genres'
  heading = soup.find('h3', class_='detail-infos__subheading', string='Genres')

  # Checking if the heading is found
  if heading:
    # Finding the next sibling div with class 'detail-infos__value'
    genre_div = heading.find_next_sibling('div', class_='detail-infos__value')

    # Checking if the genre_div is found
    if genre_div:
      # Appending the stripped text of genre_div to the tvshow_genres list
      tvshow_genres.append(genre_div.text.strip())
    else:
      # Appending 'NA' if the genre_div is not found
      tvshow_genres.append('NA')
  else:
    # Appending 'NA' if the heading is not found
    tvshow_genres.append('NA')

# Printing the list containing TV show genres for each URL
print(tvshow_genres)
len(tvshow_genres)
# Out:
# ['War & Military, Drama, History', 'Romance, Drama, History', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'Comedy', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'Action & Adventure, Crime, Drama, Mystery & Thriller', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'Crime, Drama, Mystery & Thriller, Comedy', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'Drama, Crime', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# 100

# %% [markdown]
# ## **Fetching IMDB Rating Details**

# %%
# Write Your Code here
# Initializing a dictionary to store rating values for each tv show URL
tvshow_ratings = {}

# Iterating through each  tv show URL
for url in tvshow_urls:
    # Fetching the webpage content
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')

    # Finding all div elements with class 'detail-infos'
    details_divs = soup.find_all('div', {'class':'detail-infos'})

    # Default value for rating in case it's not found
    rating_value = 'NA'

    # Iterating through each 'detail-infos' div
    for detail_div in details_divs:
        # Finding the h3 element with class 'detail-infos__subheading'
        subheading = detail_div.find('h3', {'class':'detail-infos__subheading'})

        # Checking if the subheading contains the text 'Rating'
        if subheading and 'Rating' in subheading.text:
            # Finding the next div with class 'detail-infos__value'
            rating_div = detail_div.find('div', {'class':'detail-infos__value'})

            # Checking if the rating_div is found
            if rating_div:
                # Extracting the rating value
                rating_value = rating_div.text.strip()

    # Storing the rating value in the dictionary with the  tv show URL as the key
    tvshow_ratings[url] = rating_value

# Print the dictionary containing rating values for each tv show URL
print(tvshow_ratings)
# Out:
# {'https://www.justwatch.com/in/tv-show/shogun-2024': '8.8  (121k)', 'https://www.justwatch.com/in/tv-show/heeramandi': '6.5  (23k)', 'https://www.justwatch.com/in/tv-show/panchayat': '8.9  (85k)', 'https://www.justwatch.com/in/tv-show/fallout': 'NA', 'https://www.justwatch.com/in/tv-show/mirzapur': 'NA', 'https://www.justwatch.com/in/tv-show/game-of-thrones': 'NA', 'https://www.justwatch.com/in/tv-show/3-body-problem': 'NA', 'https://www.justwatch.com/in/tv-show/dead-boy-detectives': 'NA', 'https://www.justwatch.com/in/tv-show/baby-reindeer': 'NA', 'https://www.justwatch.com/in/tv-show/apharan': 'NA', 'https://www.justwatch.com/in/tv-show/young-sheldon': 'NA', 'https://www.justwatch.com/in/tv-show/attack-on-titan': 'NA', 'https://www.justwatch.com/in/tv-show/inspector-rishi': 'NA', 'https://www.justwatch.com/in/tv-show/sunflower-2021': '7.4  (23k)', 'https://www.justwatch.com/in/tv-show/the-walking-dead': 'NA', 'https://www.justwatch.com/in/tv-show/murder-in-mahim': 'NA', 'https://www.justwatch.com/in/tv-show/aashram': 'NA', 'https://www.justwatch.com/in/tv-show/lucifer': 'NA', 'https://www.justwatch.com/in/tv-show/farzi': 'NA', 'https://www.justwatch.com/in/tv-show/a-gentleman-in-moscow': 'NA', 'https://www.justwatch.com/in/tv-show/mastram': 'NA', 'https://www.justwatch.com/in/tv-show/untitled-kapil-sharma-netflix-project': 'NA', 'https://www.justwatch.com/in/tv-show/solo-leveling-2024': 'NA', 'https://www.justwatch.com/in/tv-show/dil-dosti-dilemma': 'NA', 'https://www.justwatch.com/in/tv-show/thank-you-next': 'NA', 'https://www.justwatch.com/in/tv-show/we-were-the-lucky-ones': 'NA', 'https://www.justwatch.com/in/tv-show/ranneeti-balakot-and-beyond': 'NA', 'https://www.justwatch.com/in/tv-show/the-gentlemen': 'NA', 'https://www.justwatch.com/in/tv-show/ripley': 'NA', 'https://www.justwatch.com/in/tv-show/broken-but-beautiful': 'NA', 'https://www.justwatch.com/in/tv-show/queen-of-tears': 'NA', 'https://www.justwatch.com/in/tv-show/the-family-man': 'NA', 'https://www.justwatch.com/in/tv-show/gandii-baat': 'NA', 'https://www.justwatch.com/in/tv-show/the-rookie': 'NA', 'https://www.justwatch.com/in/tv-show/dark-matter-2024': 'NA', 'https://www.justwatch.com/in/tv-show/house-of-the-dragon': 'NA', 'https://www.justwatch.com/in/tv-show/asur': 'NA', 'https://www.justwatch.com/in/tv-show/jujutsu-kaisen': '8.6  (116k)', 'https://www.justwatch.com/in/tv-show/goodbye-earth': 'NA', 'https://www.justwatch.com/in/tv-show/true-detective': 'NA', 'https://www.justwatch.com/in/tv-show/euphoria': 'NA', 'https://www.justwatch.com/in/tv-show/maamla-legal-hai': 'NA', 'https://www.justwatch.com/in/tv-show/modern-family': 'NA', 'https://www.justwatch.com/in/tv-show/dehati-ladke': 'NA', 'https://www.justwatch.com/in/tv-show/the-last-of-us': 'NA', 'https://www.justwatch.com/in/tv-show/jack-reacher': 'NA', 'https://www.justwatch.com/in/tv-show/maharani-2021': 'NA', 'https://www.justwatch.com/in/tv-show/demon-slayer-kimetsu-no-yaiba': 'NA', 'https://www.justwatch.com/in/tv-show/house': 'NA', 'https://www.justwatch.com/in/tv-show/stranger-things': 'NA', 'https://www.justwatch.com/in/tv-show/maxton-hall-the-world-between-us': 'NA', 'https://www.justwatch.com/in/tv-show/paperhouse': 'NA', 'https://www.justwatch.com/in/tv-show/naruto-shippuden': 'NA', 'https://www.justwatch.com/in/tv-show/peaky-blinders': 'NA', 'https://www.justwatch.com/in/tv-show/naruto': 'NA', 'https://www.justwatch.com/in/tv-show/brigands-the-quest-for-gold': 'NA', 'https://www.justwatch.com/in/tv-show/the-good-doctor': 'NA', 'https://www.justwatch.com/in/tv-show/the-flash': 'NA', 'https://www.justwatch.com/in/tv-show/undekhi': 'NA', 'https://www.justwatch.com/in/tv-show/mtv-splitsvilla': 'NA', 'https://www.justwatch.com/in/tv-show/invincible': '8.7  (206k)', 'https://www.justwatch.com/in/tv-show/dark-desire': 'NA', 'https://www.justwatch.com/in/tv-show/how-i-met-your-mother': 'NA', 'https://www.justwatch.com/in/tv-show/scam-1992': 'NA', 'https://www.justwatch.com/in/tv-show/gullak': 'NA ...

# %%
# Initializing an empty list to store IMDb ratings
tvshow_imdb_ratings = []

# Iterating through each rating value in the 'ratings' dictionary
for ratings in tvshow_ratings.values():
  tvshow_imdb_ratings.append(ratings.split()[0])

# Printing the list containing IMDb ratings
print(tvshow_imdb_ratings)
print(len(tvshow_imdb_ratings))
# Out:
# ['8.8', '6.5', '8.9', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '7.4', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '8.6', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '8.7', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '8.6', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# 100

# %% [markdown]
# ## **Fetching Age Rating Details**

# %%
# Write Your Code here
# Initializing a dictionary to store age criteria for each TV show URL
tvshow_age_criteria = {}

# Iterating through each TV show URL
for url in tvshow_urls:
    # Fetching the webpage content
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    # Finding all div elements with class 'detail-infos'
    details_divs = soup.find_all('div', {'class':'detail-infos'})

    # Default value for age_rating in case it's not found
    age_rating = 'NA'

    # Iterating through each 'detail-infos' div
    for detail_div in details_divs:
        # Finding the h3 element with class 'detail-infos__subheading'
        subheading = detail_div.find('h3', {'class':'detail-infos__subheading'})

        # Checking if the subheading contains the text 'Age Rating'
        if subheading and 'Age rating' in subheading.text:
            # Finding the next div with class 'detail-infos__value'
            age_rating_div = detail_div.find('div', {'class':'detail-infos__value'})

            # Checking if the age_rating_div is found
            if age_rating_div:
                # Extracting the age rating value
                age_rating = age_rating_div.text.strip()

    # Storing the age rating value in the dictionary with the tv show URL as the key
    tvshow_age_criteria[url] =age_rating

# Print the dictionary containing age_rating_value values for each tv show URL
print(tvshow_age_criteria)
# Out:
# {'https://www.justwatch.com/in/tv-show/shogun-2024': 'NA', 'https://www.justwatch.com/in/tv-show/heeramandi': 'NA', 'https://www.justwatch.com/in/tv-show/panchayat': 'NA', 'https://www.justwatch.com/in/tv-show/fallout': 'NA', 'https://www.justwatch.com/in/tv-show/mirzapur': 'NA', 'https://www.justwatch.com/in/tv-show/game-of-thrones': 'NA', 'https://www.justwatch.com/in/tv-show/3-body-problem': 'NA', 'https://www.justwatch.com/in/tv-show/dead-boy-detectives': 'NA', 'https://www.justwatch.com/in/tv-show/baby-reindeer': 'NA', 'https://www.justwatch.com/in/tv-show/apharan': 'NA', 'https://www.justwatch.com/in/tv-show/young-sheldon': 'NA', 'https://www.justwatch.com/in/tv-show/attack-on-titan': 'NA', 'https://www.justwatch.com/in/tv-show/inspector-rishi': 'NA', 'https://www.justwatch.com/in/tv-show/sunflower-2021': 'NA', 'https://www.justwatch.com/in/tv-show/the-walking-dead': 'NA', 'https://www.justwatch.com/in/tv-show/murder-in-mahim': 'NA', 'https://www.justwatch.com/in/tv-show/aashram': 'NA', 'https://www.justwatch.com/in/tv-show/lucifer': 'NA', 'https://www.justwatch.com/in/tv-show/farzi': 'NA', 'https://www.justwatch.com/in/tv-show/a-gentleman-in-moscow': 'NA', 'https://www.justwatch.com/in/tv-show/mastram': 'NA', 'https://www.justwatch.com/in/tv-show/untitled-kapil-sharma-netflix-project': 'NA', 'https://www.justwatch.com/in/tv-show/solo-leveling-2024': 'NA', 'https://www.justwatch.com/in/tv-show/dil-dosti-dilemma': 'NA', 'https://www.justwatch.com/in/tv-show/thank-you-next': 'NA', 'https://www.justwatch.com/in/tv-show/we-were-the-lucky-ones': 'NA', 'https://www.justwatch.com/in/tv-show/ranneeti-balakot-and-beyond': 'NA', 'https://www.justwatch.com/in/tv-show/the-gentlemen': 'NA', 'https://www.justwatch.com/in/tv-show/ripley': 'NA', 'https://www.justwatch.com/in/tv-show/broken-but-beautiful': 'NA', 'https://www.justwatch.com/in/tv-show/queen-of-tears': 'NA', 'https://www.justwatch.com/in/tv-show/the-family-man': 'NA', 'https://www.justwatch.com/in/tv-show/gandii-baat': 'NA', 'https://www.justwatch.com/in/tv-show/the-rookie': 'NA', 'https://www.justwatch.com/in/tv-show/dark-matter-2024': 'NA', 'https://www.justwatch.com/in/tv-show/house-of-the-dragon': 'NA', 'https://www.justwatch.com/in/tv-show/asur': 'NA', 'https://www.justwatch.com/in/tv-show/jujutsu-kaisen': 'NA', 'https://www.justwatch.com/in/tv-show/goodbye-earth': 'NA', 'https://www.justwatch.com/in/tv-show/true-detective': 'NA', 'https://www.justwatch.com/in/tv-show/euphoria': 'NA', 'https://www.justwatch.com/in/tv-show/maamla-legal-hai': 'NA', 'https://www.justwatch.com/in/tv-show/modern-family': 'NA', 'https://www.justwatch.com/in/tv-show/dehati-ladke': 'NA', 'https://www.justwatch.com/in/tv-show/the-last-of-us': 'NA', 'https://www.justwatch.com/in/tv-show/jack-reacher': 'NA', 'https://www.justwatch.com/in/tv-show/maharani-2021': 'NA', 'https://www.justwatch.com/in/tv-show/demon-slayer-kimetsu-no-yaiba': 'NA', 'https://www.justwatch.com/in/tv-show/house': 'NA', 'https://www.justwatch.com/in/tv-show/stranger-things': 'NA', 'https://www.justwatch.com/in/tv-show/maxton-hall-the-world-between-us': 'NA', 'https://www.justwatch.com/in/tv-show/paperhouse': 'NA', 'https://www.justwatch.com/in/tv-show/naruto-shippuden': 'NA', 'https://www.justwatch.com/in/tv-show/peaky-blinders': 'NA', 'https://www.justwatch.com/in/tv-show/naruto': 'NA', 'https://www.justwatch.com/in/tv-show/brigands-the-quest-for-gold': 'NA', 'https://www.justwatch.com/in/tv-show/the-good-doctor': 'NA', 'https://www.justwatch.com/in/tv-show/the-flash': 'NA', 'https://www.justwatch.com/in/tv-show/undekhi': 'NA', 'https://www.justwatch.com/in/tv-show/mtv-splitsvilla': 'NA', 'https://www.justwatch.com/in/tv-show/invincible': 'NA', 'https://www.justwatch.com/in/tv-show/dark-desire': 'NA', 'https://www.justwatch.com/in/tv-show/how-i-met-your-mother': 'NA', 'https://www.justwatch.com/in/tv-show/scam-1992': 'NA', 'https://www.justwatch.com/in/tv-show/gullak': 'NA', 'https://www.justwatch.com/in/tv-show/breaking-b ...

# %%
# Creating a list comprehension to extract age ratings from the 'age_criteria' dictionary
tvshow_age_rating = [rating for rating in tvshow_age_criteria.values()]

# Printing the list containing age ratings
print(tvshow_age_rating)
print(len(tvshow_age_rating))
# Out:
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# 100

# %% [markdown]
# ## **Fetching Production Country details**

# %%
# Write Your Code here
# Initializing a dictionary to store production_country for each tv show url
tvshow_production_country = {}

# Iterating through each tv show url
for url in tvshow_urls:
    # Fetching the webpage content
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    # Finding all div elements with class 'detail-infos'
    details_divs = soup.find_all('div', {'class':'detail-infos'})

    # Default value for production country in case it's not found
    country = 'NA'

    # Iterating through each 'detail-infos' div
    for detail_div in details_divs:
        # Finding the h3 element with class 'detail-infos__subheading'
        subheading = detail_div.find('h3', {'class':'detail-infos__subheading'})

        # Checking if the subheading contains the text 'Production country'
        if subheading and 'Production country' in subheading.text:
            # Finding the next div with class 'detail-infos__value'
            country_div = detail_div.find('div', {'class':'detail-infos__value'})

            # Checking if the country_div is found
            if country_div:
                # Extracting the country name
                country = country_div .text.strip()

    # Storing the country name  in the dictionary with the tv show url as the key
    tvshow_production_country[url] =country

# Print the dictionary containing counry for each tv show url
print(tvshow_production_country)
# Out:
# {'https://www.justwatch.com/in/tv-show/shogun-2024': 'United States', 'https://www.justwatch.com/in/tv-show/heeramandi': 'India', 'https://www.justwatch.com/in/tv-show/panchayat': 'India', 'https://www.justwatch.com/in/tv-show/fallout': 'United States', 'https://www.justwatch.com/in/tv-show/mirzapur': 'India', 'https://www.justwatch.com/in/tv-show/game-of-thrones': 'NA', 'https://www.justwatch.com/in/tv-show/3-body-problem': 'NA', 'https://www.justwatch.com/in/tv-show/dead-boy-detectives': 'NA', 'https://www.justwatch.com/in/tv-show/baby-reindeer': 'NA', 'https://www.justwatch.com/in/tv-show/apharan': 'NA', 'https://www.justwatch.com/in/tv-show/young-sheldon': 'United States', 'https://www.justwatch.com/in/tv-show/attack-on-titan': 'NA', 'https://www.justwatch.com/in/tv-show/inspector-rishi': 'NA', 'https://www.justwatch.com/in/tv-show/sunflower-2021': 'NA', 'https://www.justwatch.com/in/tv-show/the-walking-dead': 'NA', 'https://www.justwatch.com/in/tv-show/murder-in-mahim': 'NA', 'https://www.justwatch.com/in/tv-show/aashram': 'NA', 'https://www.justwatch.com/in/tv-show/lucifer': 'NA', 'https://www.justwatch.com/in/tv-show/farzi': 'NA', 'https://www.justwatch.com/in/tv-show/a-gentleman-in-moscow': 'NA', 'https://www.justwatch.com/in/tv-show/mastram': 'NA', 'https://www.justwatch.com/in/tv-show/untitled-kapil-sharma-netflix-project': 'NA', 'https://www.justwatch.com/in/tv-show/solo-leveling-2024': 'NA', 'https://www.justwatch.com/in/tv-show/dil-dosti-dilemma': 'NA', 'https://www.justwatch.com/in/tv-show/thank-you-next': 'NA', 'https://www.justwatch.com/in/tv-show/we-were-the-lucky-ones': 'NA', 'https://www.justwatch.com/in/tv-show/ranneeti-balakot-and-beyond': 'NA', 'https://www.justwatch.com/in/tv-show/the-gentlemen': 'NA', 'https://www.justwatch.com/in/tv-show/ripley': 'NA', 'https://www.justwatch.com/in/tv-show/broken-but-beautiful': 'NA', 'https://www.justwatch.com/in/tv-show/queen-of-tears': 'NA', 'https://www.justwatch.com/in/tv-show/the-family-man': 'NA', 'https://www.justwatch.com/in/tv-show/gandii-baat': 'NA', 'https://www.justwatch.com/in/tv-show/the-rookie': 'United States', 'https://www.justwatch.com/in/tv-show/dark-matter-2024': 'NA', 'https://www.justwatch.com/in/tv-show/house-of-the-dragon': 'NA', 'https://www.justwatch.com/in/tv-show/asur': 'NA', 'https://www.justwatch.com/in/tv-show/jujutsu-kaisen': 'NA', 'https://www.justwatch.com/in/tv-show/goodbye-earth': 'NA', 'https://www.justwatch.com/in/tv-show/true-detective': 'NA', 'https://www.justwatch.com/in/tv-show/euphoria': 'NA', 'https://www.justwatch.com/in/tv-show/maamla-legal-hai': 'NA', 'https://www.justwatch.com/in/tv-show/modern-family': 'NA', 'https://www.justwatch.com/in/tv-show/dehati-ladke': 'NA', 'https://www.justwatch.com/in/tv-show/the-last-of-us': 'NA', 'https://www.justwatch.com/in/tv-show/jack-reacher': 'NA', 'https://www.justwatch.com/in/tv-show/maharani-2021': 'NA', 'https://www.justwatch.com/in/tv-show/demon-slayer-kimetsu-no-yaiba': 'NA', 'https://www.justwatch.com/in/tv-show/house': 'NA', 'https://www.justwatch.com/in/tv-show/stranger-things': 'NA', 'https://www.justwatch.com/in/tv-show/maxton-hall-the-world-between-us': 'NA', 'https://www.justwatch.com/in/tv-show/paperhouse': 'NA', 'https://www.justwatch.com/in/tv-show/naruto-shippuden': 'NA', 'https://www.justwatch.com/in/tv-show/peaky-blinders': 'United Kingdom', 'https://www.justwatch.com/in/tv-show/naruto': 'NA', 'https://www.justwatch.com/in/tv-show/brigands-the-quest-for-gold': 'NA', 'https://www.justwatch.com/in/tv-show/the-good-doctor': 'NA', 'https://www.justwatch.com/in/tv-show/the-flash': 'NA', 'https://www.justwatch.com/in/tv-show/undekhi': 'NA', 'https://www.justwatch.com/in/tv-show/mtv-splitsvilla': 'NA', 'https://www.justwatch.com/in/tv-show/invincible': 'NA', 'https://www.justwatch.com/in/tv-show/dark-desire': 'NA', 'https://www.justwatch.com/in/tv-show/how-i-met-your-mother': 'NA', 'https://www.justwatch.com/in/tv-show/scam-1992': 'NA', 'https://www.justwatch.com/in/tv-sho ...

# %%
# initialising an empty list tvshow_Production_countries
tvshow_Production_countries=[]
for country in tvshow_production_country.values():
  tvshow_Production_countries.append(country)
# Printing the list containing Production country
print(tvshow_Production_countries)
print(len(tvshow_Production_countries))
# Out:
# ['United States', 'India', 'India', 'United States', 'India', 'NA', 'NA', 'NA', 'NA', 'NA', 'United States', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'United States', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'United Kingdom', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'United States', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'India']
# 100

# %% [markdown]
# ## **Fetching Streaming Service details**

# %%
# Write Your Code here
# Initializing an empty list to store streaming platform names
tvshow_streaming_platform = []

# Iterating through each TV show URL
for url in tvshow_urls:
    # Fetching the webpage content
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    # Finding the 'img' element with class 'offer__icon'
    platform = soup.find('img', {'class':'offer__icon'})

    # Checking if the 'platform' element is found
    if platform:
        # Extracting the 'alt' attribute, which contains the platform name
        platform_name = platform['alt']
    else:
        # If 'platform' is not found, assigning 'NA' as the platform name
        platform_name = "NA"

    # Appending the platform name to the list
    tvshow_streaming_platform.append(platform_name)

# Printing the list containing streaming platform names
print(tvshow_streaming_platform)
print(len(tvshow_streaming_platform))
# Out:
# ['Hotstar', 'Netflix', 'Amazon Prime Video', 'Amazon Prime Video', 'Amazon Prime Video', 'Jio Cinema', 'Netflix', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'Jio Cinema', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'Jio Cinema', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'Netflix', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# 100

# %% [markdown]
# ## **Fetching Duration Details**

# %%
# Write Your Code here
# Initializing an empty list to store the number of seasons for each TV show
tvshow_duration = []

# Iterating through each TV show URL
for url in tvshow_urls:
    # Fetching the webpage content
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    # Finding the 'h2' element with class 'subheading'
    seasons = soup.find('h2', class_='subheading')

    # Checking if the 'seasons' element is found
    if seasons:
        # Appending the text content of 'seasons' to the 'duration' list
        tvshow_duration.append(seasons.text)
    else:
        # If 'seasons' is not found, assigning 'NA' to the 'duration' list
        tvshow_duration.append('NA')

# Printing the list containing the number of seasons for each TV show
print(tvshow_duration)
# Out:
# [' 1 Seasons ', ' 1 Seasons ', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', ' 1 Seasons ', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', ' 6 Seasons ', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', ' 7 Seasons ', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', ' 21 Seasons ', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']

# %%
#replacing 'Seasons' with 'S' in duration
tvshow_duration=[s.replace('Seasons','S') for s in tvshow_duration]
print(tvshow_duration)
print(len(tvshow_duration))
# Out:
# [' 1 S ', ' 1 S ', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', ' 1 S ', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', ' 6 S ', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', ' 7 S ', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', ' 21 S ', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# 100

# %% [markdown]
# ## **Creating TV Show DataFrame**

# %%
# Write Your Code here
# Creating a dictionary with keys as column names and values as lists
tvshow_data={'Title':tvshow_title,
            'Release_year':tvshow_release_year,
            'Genre':tvshow_genres,
            'IMDB_Rating':tvshow_imdb_ratings,
            'Age_rating':tvshow_age_rating,
            'Duration':tvshow_duration,
            'Production_country':tvshow_Production_countries,
            'Streaming_service':tvshow_streaming_platform,
            'URL':tvshow_urls
              }
# Creating a DataFrame using the dictionary
tvshow_df=pd.DataFrame(tvshow_data)

# %%
tvshow_df
# Out:
#           Title Release_year                           Genre IMDB_Rating  \
# 0   shogun-2024         2024  War & Military, Drama, History         8.8
# 1    heeramandi         2024         Romance, Drama, History         6.5
# 2     panchayat         2020                              NA         8.9
# 3       fallout         2024                              NA          NA
# 4      mirzapur         2018                              NA          NA
# ..          ...          ...                             ...         ...
# 95   kaiju-no-8           NA                              NA          NA
# 96    wednesday           NA                              NA          NA
# 97          you         2018                              NA          NA
# 98         lost           NA                              NA          NA
# 99      sarkaar           NA                              NA          NA
#
#    Age_rating Duration Production_country   Streaming_service  \
# 0          NA     1 S       United States             Hotstar
# 1          NA     1 S               India             Netflix
# 2          NA       NA              India  Amazon Prime Video
# 3          NA       NA      United States  Amazon Prime Video
# 4          NA       NA              India  Amazon Prime Video
# ..        ...      ...                ...                 ...
# 95         NA       NA                 NA                  NA
# 96         NA       NA                 NA                  NA
# 97         NA       NA                 NA                  NA
# 98         NA       NA                 NA                  NA
# 99         NA       NA              India                  NA
#
#                                                  URL
# 0   https://www.justwatch.com/in/tv-show/shogun-2024
# 1    https://www.justwatch.com/in/tv-show/heeramandi
# 2     https://www.justwatch.com/in/tv-show/panchayat
# 3       https://www.justwatch.com/in/tv-show/fallout
# 4      https://www.justwatch.com/in/tv-show/mirzapur
# ..                                               ...
# 95   https://www.justwatch.com/in/tv-show/kaiju-no-8
# 96    https://www.justwatch.com/in/tv-show/wednesday
# 97          https://www.justwatch.com/in/tv-show/you
# 98         https://www.justwatch.com/in/tv-show/lost
# 99      https://www.justwatch.com/in/tv-show/sarkaar
#
# [100 rows x 9 columns]

# %%
tvshow_df.head()
# Out:
#          Title Release_year                           Genre IMDB_Rating  \
# 0  shogun-2024         2024  War & Military, Drama, History         8.8
# 1   heeramandi         2024         Romance, Drama, History         6.5
# 2    panchayat         2020                              NA         8.9
# 3      fallout         2024                              NA          NA
# 4     mirzapur         2018                              NA          NA
#
#   Age_rating Duration Production_country   Streaming_service  \
# 0         NA     1 S       United States             Hotstar
# 1         NA     1 S               India             Netflix
# 2         NA       NA              India  Amazon Prime Video
# 3         NA       NA      United States  Amazon Prime Video
# 4         NA       NA              India  Amazon Prime Video
#
#                                                 URL
# 0  https://www.justwatch.com/in/tv-show/shogun-2024
# 1   https://www.justwatch.com/in/tv-show/heeramandi
# 2    https://www.justwatch.com/in/tv-show/panchayat
# 3      https://www.justwatch.com/in/tv-show/fallout
# 4     https://www.justwatch.com/in/tv-show/mirzapur

# %%
tvshow_df.tail()
# Out:
#          Title Release_year Genre IMDB_Rating Age_rating Duration  \
# 95  kaiju-no-8           NA    NA          NA         NA       NA
# 96   wednesday           NA    NA          NA         NA       NA
# 97         you         2018    NA          NA         NA       NA
# 98        lost           NA    NA          NA         NA       NA
# 99     sarkaar           NA    NA          NA         NA       NA
#
#    Production_country Streaming_service  \
# 95                 NA                NA
# 96                 NA                NA
# 97                 NA                NA
# 98                 NA                NA
# 99              India                NA
#
#                                                 URL
# 95  https://www.justwatch.com/in/tv-show/kaiju-no-8
# 96   https://www.justwatch.com/in/tv-show/wednesday
# 97         https://www.justwatch.com/in/tv-show/you
# 98        https://www.justwatch.com/in/tv-show/lost
# 99     https://www.justwatch.com/in/tv-show/sarkaar

# %%
tvshow_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               100 non-null    object
#  1   Release_year        100 non-null    object
#  2   Genre               100 non-null    object
#  3   IMDB_Rating         100 non-null    object
#  4   Age_rating          100 non-null    object
#  5   Duration            100 non-null    object
#  6   Production_country  100 non-null    object
#  7   Streaming_service   100 non-null    object
#  8   URL                 100 non-null    object
# dtypes: object(9)
# memory usage: 7.2+ KB

# %%
# Replace 'NA' with NaN (Not a Number)
tvshow_df['IMDB_Rating'].replace('NA',float('nan'),inplace=True)

# Convert the 'IMDB_Rating' column to float
tvshow_df['IMDB_Rating'] = tvshow_df['IMDB_Rating'].astype(float)

# %%
# Combining both movie_df and tvshow_df into single DataFrame
final_df=pd.concat([movie_df,tvshow_df])
final_df
# Out:
#                Title Release_year  \
# 0    laapataa-ladies         2024
# 1        article-370         2024
# 2     manjummel-boys         2024
# 3        family-star         2024
# 4   black-magic-2024         2024
# ..               ...          ...
# 95        kaiju-no-8           NA
# 96         wednesday           NA
# 97               you         2018
# 98              lost           NA
# 99           sarkaar           NA
#
#                                             Genre  IMDB_Rating Age_rating  \
# 0                                   Drama, Comedy          8.5         UA
# 1   Action & Adventure, Drama, Mystery & Thriller          8.0         NA
# 2   Mystery & Thriller, Action & Adventure, Drama          8.4         UA
# 3      Action & Adventure, Drama, Comedy, Romance          5.1         NA
# 4                                              NA          6.8         UA
# ..                                            ...          ...        ...
# 95                                             NA          NaN         NA
# 96                                             NA          NaN         NA
# 97                                             NA          NaN         NA
# 98                                             NA          NaN         NA
# 99                                             NA          NaN         NA
#
#     Duration Production_country Streaming_service  \
# 0    2h 2min              India           Netflix
# 1   2h 38min              India           Netflix
# 2   2h 15min                 NA           Hotstar
# 3   2h 39min                 NA                NA
# 4   2h 12min                 NA                NA
# ..       ...                ...               ...
# 95        NA                 NA                NA
# 96        NA                 NA                NA
# 97        NA                 NA                NA
# 98        NA                 NA                NA
# 99        NA              India                NA
#
#                                                   URL
# 0   https://www.justwatch.com/in/movie/laapataa-la...
# 1      https://www.justwatch.com/in/movie/article-370
# 2   https://www.justwatch.com/in/movie/manjummel-boys
# 3      https://www.justwatch.com/in/movie/family-star
# 4   https://www.justwatch.com/in/movie/black-magic...
# ..                                                ...
# 95    https://www.justwatch.com/in/tv-show/kaiju-no-8
# 96     https://www.justwatch.com/in/tv-show/wednesday
# 97           https://www.justwatch.com/in/tv-show/you
# 98          https://www.justwatch.com/in/tv-show/lost
# 99       https://www.justwatch.com/in/tv-show/sarkaar
#
# [200 rows x 9 columns]

# %%
#head of final DataFrame
final_df.head(10)
# Out:
#                                      Title Release_year  \
# 0                          laapataa-ladies         2024
# 1                              article-370         2024
# 2                           manjummel-boys         2024
# 3                              family-star         2024
# 4                         black-magic-2024         2024
# 5                                  premalu         2024
# 6                            dune-part-two         2024
# 7                            aavesham-2024         2024
# 8                            the-crew-2024         2024
# 9  untitled-shahid-kapoor-kriti-sanon-film         2024
#
#                                            Genre  IMDB_Rating Age_rating  \
# 0                                  Drama, Comedy          8.5         UA
# 1  Action & Adventure, Drama, Mystery & Thriller          8.0         NA
# 2  Mystery & Thriller, Action & Adventure, Drama          8.4         UA
# 3     Action & Adventure, Drama, Comedy, Romance          5.1         NA
# 4                                             NA          6.8         UA
# 5                                             NA          NaN          U
# 6                                             NA          NaN         NA
# 7                                             NA          NaN         NA
# 8                                             NA          NaN         NA
# 9                                             NA          NaN         NA
#
#    Duration Production_country Streaming_service  \
# 0   2h 2min              India           Netflix
# 1  2h 38min              India           Netflix
# 2  2h 15min                 NA           Hotstar
# 3  2h 39min                 NA                NA
# 4  2h 12min                 NA                NA
# 5  2h 36min                 NA                NA
# 6  2h 47min      United States                NA
# 7  2h 38min                 NA                NA
# 8  1h 58min                 NA                NA
# 9  2h 21min                 NA                NA
#
#                                                  URL
# 0  https://www.justwatch.com/in/movie/laapataa-la...
# 1     https://www.justwatch.com/in/movie/article-370
# 2  https://www.justwatch.com/in/movie/manjummel-boys
# 3     https://www.justwatch.com/in/movie/family-star
# 4  https://www.justwatch.com/in/movie/black-magic...
# 5         https://www.justwatch.com/in/movie/premalu
# 6   https://www.justwatch.com/in/movie/dune-part-two
# 7   https://www.justwatch.com/in/movie/aavesham-2024
# 8   https://www.justwatch.com/in/movie/the-crew-2024
# 9  https://www.justwatch.com/in/movie/untitled-sh...

# %%
#tail of Final DataFrame
final_df.tail(10)
# Out:
#                              Title Release_year         Genre  IMDB_Rating  \
# 90                better-call-saul           NA  Drama, Crime          NaN
# 91                  under-the-dome           NA            NA          NaN
# 92                      paatal-lok           NA            NA          NaN
# 93                       spartacus           NA            NA          NaN
# 94  adrishyam-the-invisible-heroes           NA            NA          NaN
# 95                      kaiju-no-8           NA            NA          NaN
# 96                       wednesday           NA            NA          NaN
# 97                             you         2018            NA          NaN
# 98                            lost           NA            NA          NaN
# 99                         sarkaar           NA            NA          NaN
#
#    Age_rating Duration Production_country Streaming_service  \
# 90         NA       NA                 NA                NA
# 91         NA       NA                 NA                NA
# 92         NA       NA                 NA                NA
# 93         NA       NA                 NA                NA
# 94         NA       NA                 NA                NA
# 95         NA       NA                 NA                NA
# 96         NA       NA                 NA                NA
# 97         NA       NA                 NA                NA
# 98         NA       NA                 NA                NA
# 99         NA       NA              India                NA
#
#                                                   URL
# 90  https://www.justwatch.com/in/tv-show/better-ca...
# 91  https://www.justwatch.com/in/tv-show/under-the...
# 92    https://www.justwatch.com/in/tv-show/paatal-lok
# 93     https://www.justwatch.com/in/tv-show/spartacus
# 94  https://www.justwatch.com/in/tv-show/adrishyam...
# 95    https://www.justwatch.com/in/tv-show/kaiju-no-8
# 96     https://www.justwatch.com/in/tv-show/wednesday
# 97           https://www.justwatch.com/in/tv-show/you
# 98          https://www.justwatch.com/in/tv-show/lost
# 99       https://www.justwatch.com/in/tv-show/sarkaar

# %%
#final DataFrame info
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               200 non-null    object
#  1   Release_year        200 non-null    object
#  2   Genre               200 non-null    object
#  3   IMDB_Rating         15 non-null     float64
#  4   Age_rating          200 non-null    object
#  5   Duration            200 non-null    object
#  6   Production_country  200 non-null    object
#  7   Streaming_service   200 non-null    object
#  8   URL                 200 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 15.6+ KB

# %% [markdown]
# ## **Task 2 :- Data Filtering & Analysis**

# %%
#Filter to include only recent releases (last 2 years) with IMDb ratings of 7 or higher.

filter_data=final_df[(final_df["Release_year"] >='2022') & (final_df["IMDB_Rating"] >= 7 )]
filter_data
# Out:
#                              Title Release_year  \
# 0                  laapataa-ladies         2024
# 1                      article-370         2024
# 2                   manjummel-boys         2024
# 5                          premalu         2024
# 6                    dune-part-two         2024
# ..                             ...          ...
# 94  adrishyam-the-invisible-heroes           NA
# 95                      kaiju-no-8           NA
# 96                       wednesday           NA
# 98                            lost           NA
# 99                         sarkaar           NA
#
#                                             Genre  IMDB_Rating Age_rating  \
# 0                                   Drama, Comedy          8.5         UA
# 1   Action & Adventure, Drama, Mystery & Thriller          8.0         NA
# 2   Mystery & Thriller, Action & Adventure, Drama          8.4         UA
# 5                                              NA          7.4          U
# 6                                              NA          7.4         NA
# ..                                            ...          ...        ...
# 94                                             NA          7.4         NA
# 95                                             NA          7.4         NA
# 96                                             NA          7.4         NA
# 98                                             NA          7.4         NA
# 99                                             NA          7.4         NA
#
#     Duration Production_country Streaming_service  \
# 0    2h 2min              India           Netflix
# 1   2h 38min              India           Netflix
# 2   2h 15min                 NA           Hotstar
# 5   2h 36min                 NA                NA
# 6   2h 47min      United States                NA
# ..       ...                ...               ...
# 94        NA                 NA                NA
# 95        NA                 NA                NA
# 96        NA                 NA                NA
# 98        NA                 NA                NA
# 99        NA              India                NA
#
#                                                   URL
# 0   https://www.justwatch.com/in/movie/laapataa-la...
# 1      https://www.justwatch.com/in/movie/article-370
# 2   https://www.justwatch.com/in/movie/manjummel-boys
# 5          https://www.justwatch.com/in/movie/premalu
# 6    https://www.justwatch.com/in/movie/dune-part-two
# ..                                                ...
# 94  https://www.justwatch.com/in/tv-show/adrishyam...
# 95    https://www.justwatch.com/in/tv-show/kaiju-no-8
# 96     https://www.justwatch.com/in/tv-show/wednesday
# 98          https://www.justwatch.com/in/tv-show/lost
# 99       https://www.justwatch.com/in/tv-show/sarkaar
#
# [174 rows x 9 columns]

# %% [markdown]
# ## **Calculating Mean IMDB Ratings for both Movies and Tv Shows**

# %%
movie_df['IMDB_Rating'].fillna(movie_df['IMDB_Rating'].astype(float).mean(), inplace=True)
movie_df['IMDB_Rating']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5e7d6e056e59> in <cell line: 1>()
# ----> 1 movie_df['IMDB_Rating'].fillna(movie_df['IMDB_Rating'].astype(float).mean(), inplace=True)
#       2 movie_df['IMDB_Rating']
#
# NameError: name 'movie_df' is not defined

# %%
tvshow_df['IMDB_Rating'].fillna(tvshow_df['IMDB_Rating'].astype(float).mean(), inplace=True)
tvshow_df['IMDB_Rating']

# %%
#determining average ratings for movie_df
print("Mean IMDB Ratings:")
movie_df.agg({'IMDB_Rating':'mean'})

# %%
#determining average ratings for tvshow_df
print("Mean IMDB Ratings:")
tvshow_df.agg({'IMDB_Rating':'mean'})

# %%
final_df['IMDB_Rating'].fillna(final_df['IMDB_Rating'].astype(float).mean(), inplace=True)
final_df['IMDB_Rating']

# %%
print("Mean IMDb Ratings:")
final_df.groupby('Title').agg({'IMDB_Rating':'mean'})

# %% [markdown]
# ## **Analyzing Top Genres**

# %%
# Write Your Code here
#Showing Top Genres in Movie using Word Cloud

#import all necessary Labraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Extracting genres and joining them into a single string
all_genres_text = ', '.join(final_df['Genre'].fillna('').values)
all_genres_text
# Out:
# 'Drama, Comedy, Action & Adventure, Drama, Mystery & Thriller, Mystery & Thriller, Action & Adventure, Drama, Action & Adventure, Drama, Comedy, Romance, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, Action & Adventure, Comedy, Drama, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, Romance, Drama, Sport, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, Mystery & Thriller, Action & Adventure, Crime, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, Drama, Science-Fiction, NA, NA, NA, NA, NA, NA, War & Military, Drama, History, Romance, Drama, History, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, Comedy, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, Action & Adventure, Crime, Drama, Mystery & Thriller, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, Crime, Drama, Mystery & Thriller, Comedy, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, Drama, Crime, NA, NA, NA, NA, NA, NA, NA, NA, NA'

# %%
#Let's Visvalize it using word cloud
# Creating a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='Black').generate(all_genres_text)

# Displaying the WordCloud
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of TV Show Genres')
plt.show()

# %% [markdown]
# ## **Finding Predominant Streaming Service**

# %%
# Write Your Code here
#finding Predominant Streaming Service in Movies
final_df['Streaming_service'].value_counts()
# Out:
# Streaming_service
# NA                    183
# Amazon Prime Video      6
# Netflix                 5
# Jio Cinema              3
# Hotstar                 2
# Apple TV                1
# Name: count, dtype: int64

# %%
#Let's Visvalize it using word cloud

# Extracting streaming service and joining them into a single string
all_streaming_text = ', '.join(movie_df['Streaming_service'].fillna('').values)

# Creating a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='Black').generate(all_streaming_text)

# Displaying the WordCloud
plt.figure(figsize=(12, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Movie Streaming Service')
plt.show()

# %% [markdown]
# ## **Task 3 :- Data Export**

# %%
#saving final dataframe as Final Data in csv format
final_df.to_csv('Final Data.csv',index=False)

# %%
#saving filter data as Filter Data in csv format
filter_data.to_csv('Filtered Data.csv',index=False)

# %% [markdown]
# # **Dataset Drive Link (View Access with Anyone) -**

# %% [markdown]
# # ***Congratulations!!! You have completed your Assignment.***
